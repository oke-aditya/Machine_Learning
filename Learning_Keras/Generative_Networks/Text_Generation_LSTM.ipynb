# %% [markdown]
# # Using LSTMs to generate Data

# %% [markdown]
# ## Process of generating Data
#
# 1. Input data is converted using language model
# 2. Learn this probalbility distribution.
#
# During testing time
# - After learning sample for the next character.
#
# - To control the sampling we introduce a temperature factor, which will allow us to control amount of sampling that we are doing.
#
# - Use temperature factor to control amount of randomness.
# Higher temperature factor means we get more novel and interesting text but it is inaccurate.
#
# - Lower temperature factor means consistent text but that will not make the text interesting.

# %%
import numpy as np

# %%
def reweight_distribution(original_distribution, temperature=0.5):
    # Original distribution is a probability distrubtion hence sum of all is 1.
    # Temperature will quantify the distribution
    distribution = np.log(original_distribution / temperature)
    distributoion = np.exp(distribution)
    return (distribution / np.sum(distribution))  
    # Returns reweighted distribution. Sum of distribution 
    # may not be 1, so we need to divide it.

# %% [markdown]
# # Implementating Character level LSTM

# %%
from keras.utils import get_file
import numpy as np
from keras import layers
from keras.models import Sequential
from keras import optimizers
import random
import sys

# %%
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

# %%
# print(text)

# %%
print("Corpus Text: ", len(text))
# Out:
# Corpus Text:  600893

# %% [markdown]
# Next, you’ll extract partially overlapping sequences of length maxlen, one-hot encode them, and pack them in a 3D Numpy array x of shape. `(sequences, maxlen, unique_characters)`
#
# Simultaneously, you’ll prepare an array y containing the corresponding
# targets: the one-hot-encoded characters that come after each extracted
# sequence.

# %%
maxlen = 60 # Maximum length of 60 characters
step = 3  # Sampling after every 3 characters
sentences = []   # Our X training data
next_chars = []  # Labels

# %%
for i in range(0, len(text) - maxlen, step):
    # Creating the sentece window, of length maxlen
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])

print("Number of seqeuences : ", len(sentences))
# Out:
# Number of seqeuences :  200278

# %%
# List of unique characters
# in the corpus
chars = sorted(list(set(text)))
print("Number of unique characters : ", len(chars))
# Out:
# Number of unique characters :  57

# %%
# Dictionary that maps
# unique characters to their
# index in the list “chars
char_indices = {}
for char in chars:
    char_indices[char] = chars.index(char)

# %%
# print(sentences)

# %%
# print(next_chars)

# %%
# print(chars)

# %%
print("Vectorizing: ")
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
print(x.shape)
print(y.shape)

# Sentences is a list of individual sentence.
# We go thorough every character in the sentence, mark the corresponding
# value of char in sentence as t.
# We store i as it denotes the batch_number.

# We store the batch_number and the corresponding next character in y.

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1

    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorizing:
# (200278, 60, 57)
# (200278, 57)

# %%
model = Sequential()
model.add(layers.LSTM(64, activation='tanh', recurrent_dropout=0.2, dropout=0.2, 
                      input_shape = (maxlen, len(chars)), return_sequences=False))
# model.add(layers.LSTM(32, return_sequences=True))
# model.add(layers.LSTM(16, return_sequences=False))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 64)                31232
# _________________________________________________________________
# dense_4 (Dense)              (None, 57)                3705
# =================================================================
# Total params: 34,937
# Trainable params: 34,937
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = optimizers.Adam(lr=0.015, decay=0.001)
model.compile(loss = 'categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# 1. Draw from the model a probability distribution for the next character, given the
# generated text available so far.
# 2. Reweight the distribution to a certain temperature.
# 3. Sample the next character at random according to the reweighted distribution.
# 4. Add the new character at the end of the available text.

# %%
def sample(preds, temperature=1):
    preds = np.asarray(preds).astype('float64')
    # Use the sampling temperature and control the predictions
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    # Pick according to probability the numpy function does it
    # It samples from a muiltinomial distribution
    probabs = np.random.multinomial(1, preds, 1)
    return(np.argmax(probabs))

# %%
for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)  # Fits the model for 1 iteration of the data

    # We test our model by sampling a random set of strings from the data
    # Then converting them into one-hot vectors.
    # We predict the next character add the new character to the sampled data
    # Then again continue with the predictions.

    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('-------Generation random text with seed --------')
    print(generated_text)

    for temperature in [0.2,0.5,0.8,1.2,1.4]:
        print('--------Temperature----------', temperature)
        # print('Generated text --------- ')
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1
            
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            # Need to remove one prediction which we actually didn't make
            generated_text = generated_text[1:]
            print(next_char, end = '')

        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 163s 812us/step - loss: 1.9356
# -------Generation random text with seed --------
# ublime, also of the loathsome and dreadful, still greater di
# --------Temperature---------- 0.2
# sting of the scient of the self the sention of the surtation of the such and the sention of the sention of the such of the sention of the spility and the preation of the decist of the sention and the senting of the sention and in the sention of the section of the spirition of the sentess of the sention of the spirition of the senting the sention of the spile of the some and decertion of the some t
# --------Temperature---------- 0.5
# o be some in in the ened to as which be some the gre of the sure and will in the prosont the deprition of the proprence that the and live what its and every of parizate and the compals of the sense be the deal and decommand lave of all the section the soul suppally to listerself and and not that the senteress and with as expals of case the greent the reaces the the proparity the readise of the pri
# --------Temperature---------- 0.8
# ence madiged, it ond faoudition to
# the has germans, to be distaris! the qusires, and geys hach for of spilare reang perss; the realto these prablentence some san to most which the philose fon rely toat it gene which the servery of agence claise wat all beold stef in, that the gechen those far the betoush of or enewn reences we to venest and it only
# to mother deact his it ordink, and most broughs o
# --------Temperature---------- 1.2
# nlys to 5ouphe of inmeent for mef in
# lifigicans derenplunt and catongdhstely of
# the mold to tamtt of indeess, themesis, belee of praces. sad
# in which not eulst
# from and
# spilual, age us his criccisont! bow how heve's as debldial, mays
# mire whece fa worod than most de isporvyneritivation?" e hamost, of. when word): alwams-is frempent: our,-intinrathire vase arferstialike," we sorkigistain voutaul),
# --------Temperature---------- 1.4
# tooof ene (froves for battiut of "mermolions--
# 86.
# 9381.
# weragegles bt are let by to pei4z,--wo resulle--thiy he foccilal forttandvoit beder.
# willegic! of heven and reystimul mous suffect us thene insiwh dwweol.
# is
# ibittrifirins. that prefoate), "gover kwerl as
# a ply", ssribthpolnases to nge uncogus bescufous
# peoiblisn s're. we panm to god.
#
# 1]
#
#
#
#  y.
#
#
# 110'." sucter"
# withne
# cqisposs obim of a
# t
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 160s 798us/step - loss: 1.9242
# -------Generation random text with seed --------
# tion and
# thinking, but it is above all an emotion, and in fa
# --------Temperature---------- 0.2
# n the sention and the senter and senter the senter the spirition of the all the scare of the sentice and for the such and the sention of the section of the sention of the senting the present and such the secist of the consting the such and and a some of the really and the senter of the some the senter to and streation of the sention of the sention of the senter of the secient of the such and preat
# --------Temperature---------- 0.5
# ion of a some for to and the seart, and complest of a spiciated more and mact of the reconce and secist and which a more and that the perise to precoutions of the fare and and it is and that which perter in some of the somenter as the sugh contand and most of the man the world of the beconteres to the consight as the distring of the sconse and the way who be fature that the resparity and perple to
# --------Temperature---------- 0.8
#  fral caligions and in posse as hat is it reforite.=--in the seiven whan and cand will for ente for the sult the way lomans pan
# evelod to this the man now replacted
# to form ferreds and perptencely and to live of becous and the dign and should flocesty the bakers but their condection of
# the more and concaint, mist theys which _amulity son is
# which them concimilize of more
# have long as the analles o
# --------Temperature---------- 1.2
# f these thrike hived acseatian
# droved's, restrispence one will kothe
# wha sholve in dat fow piessions
# (blle of he
# may part over dorit the e'gal commank arigl asd wostionation, bemormy howen wablive furnor as maing?s how godedet, infalited, canculty. the sefelty, hanfurirane:
# thely take: powhn it lisfo, suppress? samity, vigner panderapiteous as
# actinan varyly,
# .
#
# 1986 nal them and may
# wawly per. fu
# --------Temperature---------- 1.4
# dat--faes hus juwiz, gen's affa) to has hadfor woweranch dtld to
# gracce worlineug that ence.=--244? the raen-thing ratofurd, why lekp
# condarily dlwaed or eits, complt "delelvess nomopulnectm of
# iminecifundy not?gizaby fitionto, obeymot;
# refoint hill
# of hygles ewes--"hter lat, remem nve treims"? which gotett impurts--virher, that is fane, "=mave ell
# cand
# a
# txbut whech ticand, those
# the quakusaly
# to
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 158s 787us/step - loss: 1.9151
# -------Generation random text with seed --------
# orm of semi-barbarity that has at any time existed on earth;
# --------Temperature---------- 0.2
#  the sention of the scient of the self and in the self the self the scient of the senter of the preated the senter and the persing the sention and the sention of the persire and the sention of the sention of the self and the man the self and the self and the sention of the senter of the self the most and some the propent the self and the self and more a sould the secile of the sent of the ence of
# --------Temperature---------- 0.5
# the cain self with the such, who lose will who belies which the precolitions in the all its in the extances and greation and in as all the world and with who he all prignent of the are the fast and compless of the all the san as the maning the some his a man
# proted to man the men of in the virtuess of whech of who the greation of the secist not to have all the
# endion as had be to must the still wh
# --------Temperature---------- 0.8
# ich prieal to "way, be also and scivess of be not or the fore the fass and the gelity. he preave trut and b veritly, with he spirion of their and man the
# werders welly not the called and which the scare, and the deriruse all are themself wimpeald soully
# must sother afthes we spich man to madity, of he one to such detoness to sach as the mente and pleion. that romely as even in the is mess, by are
#
# --------Temperature---------- 1.2
# to that syclows us dempulabes rir the e
# ond sse? eever starty probutic, be init formoshic one mith converfeations nat!ky, for uncatuliti(nfur inermost lelinablecps avey with how wistn--the onlfror, of bit elvirtstide and stion; the boubce is enders imsist". the congciancs ou hogility
# artilly and long on compireteing frol we desacir permence his
# sonvally bad in
# them all the divighe, who weurlet cou
# --------Temperature---------- 1.4
# cks.
#
# 269..
# =chrequois. ne grof should (maik
# fank overnolt distenfof gownation, mugr
# is usl reads tut concreacce sen. ttupurst the
# weilys nouch ofpleal! may
# if vereprest faugh, by hemdad, the mume. which;
# is costriky, as
# ra a detighs nes sould. the vall" to of hikitars
# good in_air itsess and lems, spicerfuy s llugs
# prespence,
# lakifernes
# that a
# sobllang just that whendive enve "but in a meigh mast
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 159s 793us/step - loss: 1.9079
# -------Generation random text with seed --------
# perhaps trading or cattle-rearing communities), or upon
# old
# --------Temperature---------- 0.2
# the sention of the self the sention of the scient of the present of the spile of the such the all the scient of the such and and the such as one and such of the self and the self and the all the scient of the sention of the sention of the world the such and the and the man the self of the sention of the such and the self and the preally of the such and preation of the sention of the fact to the se
# --------Temperature---------- 0.5
# cise of the good and love of the relain the ereatal may of even the such of the weal consequent of the preach in the heard he deconse of en and the cand the will of with who decesse will perman spice of the sparity in the conse in the for the spile of the decughation of the weal the espirize and and must in the vility of on in the
# secient of the success, it in the devery world the lake on the new
# --------Temperature---------- 0.8
# and
# digness
# personce, the agapice be in the and destible--it is chulting end
# to
# which the science indery whom a that be is the
# himphers, that he his when the pholon in the and hearned beligion,
# ruch than theen is the scieture to perpors diveny to harners only actoons it is such nakerpinive, belight nimple as the relatable we on it inoan expially
# becerdered all that begartely and manger and the wau
# --------Temperature---------- 1.2
# sing (to ju0ked of the forms ofle neelf, wimlly the much re mugh low-tipsicare; ruighly beans plearys). for is i munst, to phirommol vexcepnep. lithed pattimung, abyrperly refustsannt how. fir
# it geys of his eevalther is no vage out subence a popose symidumss--wouls anke sprable; which hearsion, the hrible and fiffere by molenosing amfold darz myrizence compreciever:
# glaud, bely: inbain. of a vick
# --------Temperature---------- 1.4
#  thein they
# htin
# of when: bo:
# cause has fremeders with geperhts.mak! sesfrhen a rable reelde!
# [ cclalpasionent to
# kdrewiruden of at
# oully, mord ony
# ten_ we, velfuringly, commany:--the sppsihed; thang ond
# jusk and itpanees"
# geouly
# befongel puvrot, nan
# "us yatuars leatimeds demisk, likes is
# (winlty; to the
# cateluanrearizabus and crfadeg8e hut ocrixudific of
# proquaces
# their ;c--who c.
# te. there "for
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 159s 796us/step - loss: 1.9012
# -------Generation random text with seed --------
# on
# to the day in which he lives; his enemy has always been t
# --------Temperature---------- 0.2
# he such and will the all the spirition of the preally and the senter of the preation of the such in the such and the sense of the such and the religion of the sention of the presist of the such and the senter and consting the such and the senter and the man the man the secience of the such and such and and the san the preation of the sention of the san the preally and and deconce of the such and t
# --------Temperature---------- 0.5
# he euritued of spirition to a some the have decught and relight and the enallosophy to wat hower and possion of hus the eave of the lang there all the prepred of the word to the rance in his ond man a preace and men the grespority of like the eling their concerce are distans and man who comprestion, and estence of the mampants of the preary and the spict be resting of such and deconter and which i
# --------Temperature---------- 0.8
# njuct the concess: the world as his man
# the perard all more with
# dirker of mare or decong a moral not the
# decisialse it inclablosing the rature becour the remens), bet not which shems of moratice of sthing ement but the quexually the stays, and concerition of to amsults it is mame have for he
# the san of
# peris, which as into with is all in deling bring the reconte he sich appense secely extration t
# --------Temperature---------- 1.2
# rual
# bowins howind precerving. the loces, wosisabiaoiy, at an timudicl setivonce of itpelless goow
# who has enout inmich enemis, mis have
# the reall bhich disposverat, the
# objerty agood
# san foituscalte, enjorglus
# in wran
# which of te hodenedtary. the reas but it jussing, to flelec: everyef that syfe of connemant it parion i for to dose horgureable:--ut by chind were what huts,
# shilnal caruc). such as
# --------Temperature---------- 1.4
#  "passes, and fand esceptrs, will great, theag's
# sthe
# de a byees and exvery), shates! thay theed;-genain. disctarnch-ar pahs--name the nasurts, boted. the
# cacted, noo hich
# he zime of "frats.
# -anout grawintion of the datuial
# there courstic netmoaction
# orferisocets.=-dikouct): it sufrakm. in pospace, sen a ks,
# be hhas wath that liver's stysituble to grous iffaspe;
# the suculese knowlozides velongnee'
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 160s 797us/step - loss: 1.8963
# -------Generation random text with seed --------
# as) and therefore is it
# in the worst sense barbarous, asiati
# --------Temperature---------- 0.2
# on of the sention of the presence of the constion of the some the such and the sention of the spirit of the spirit the sention of the some the such and the such and and the such and the senter of the such and in the scient of the senter the sention of the spill and the senter and the spirit the sention of the self to a some the sention of the such and in the spirit the man the present of the senti
# --------Temperature---------- 0.5
# ons of the grest of the for the dast, and in the all and decase he cand and to presention of the wally and and for the siffering of the sentions the such and in the such and even suphy and a pereally the pressicies of the greable in the spection of or them in the fast the self to and instrean in the proposion of the conders as a pain to consture, in the senters it and
# will constan in the man to lo
# --------Temperature---------- 0.8
# ve
# and star--for to the
# hore presentions
# as his not tut the reliferg, and and inctnacied and in moopless to reif such this lets lives of the prous the a camard plain who thing to the now of respuct of the sigres which it it eveans for perperally his the coldowe which the medsented--the posing in the spince, the casty
# must. that such compected more man his will of in the since is and stall" fe carn
# --------Temperature---------- 1.2
# asions: beligh a fore exlequotose the wel
# "purtunce; so be hand reagosophing a tert eved,. long astold which the
# part the
# ruabth wat lipatins, genarmy mist that belight of howads oge their ental in own pontoe.
#
# vom,
# allo wor, or ever
# suparned myself throuh which every whak evil,
# mafse (nound
# justaran rythings of the proces and somfee-sack of corble
# bat by, secem son doefs a perms of rable thak
# sai
# --------Temperature---------- 1.4
# chtally
# "we
# thunkensess of in the-strneved: casanding te
# ispla-yand are imtility
# genolod mists;
#
# 12]-"will hims fe
# reation.=--withoring int" inder-inoccosliagicic. werhssif, wisk! choonnintsrle, givitu, with in
# arlong asse is evil prespy his tegnom, vexieve. gltion belucal ibpost injuvig?"
# 6300. cand upodes wo thas quabuliseg _receverism", mugh
# as agewhich," epgly awn lap of be ze towithertine, wh
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 157s 784us/step - loss: 1.8921
# -------Generation random text with seed --------
# urance. and not only individual men but
# all mankind will by
# --------Temperature---------- 0.2
# the propent of the such has the sention of the such and the sented and the such and all the some the eart and precears of the self to the will the such and as the sention of the scient of the real of the sented and and the some and the self and the some the sention of the sention of the reals and self the preation of the sention of the spirit of the precession of the sention of the preself and and
# --------Temperature---------- 0.5
#  in a caures. he excent the mankent in the suth in
# the way have and the enting of many prest of and who had which and to a prenest it is all and san the suring of the ward to the precert and should and his the way and the with its for one not in the sciles of the recerce of came in which the wister and becautation ear the rention of the manken and as a the with the free will in mist and expertance
# --------Temperature---------- 0.8
# --who every
# boolly recoldicacly for placal cappection to hus genes even propeduction it the gre ame aft bit sother quant, on as suct hight on expermant one deevery with domer of hading sange how all have butut of them all and becist in a complans of the for he word somet to lard the philosophy we law just the somanion
# of greation it of the entaps one sted? ane the morm the garm, the sesines, and g
# --------Temperature---------- 1.2
# rtarly and fart whathdenan" dist is sheabliaged
# sulblite unenated haw who equestory infumene, yo prese-deliguamos's withong to their truncts from strild whet objenly, as the aking man."
# "oge burblink ester," belw commicinggs--bely carmidaun braid be t boughat.
#
# whe
# hatuce as is
# proesooued evodidy deconssithoraze. he sasuls; low rear. run-gersolop: exelgioustly rey one know
# to prepution mordury
# gla
# --------Temperature---------- 1.4
# scal
# liawr (but had desupinquure in" invere sycas wolddity, and kisfue of havolly is untoule of had
# wind," and necoman
# it if, knoer.,
# is duutse somelig compareroble
# levaing b sacced,
# envermo vertle. in. in yould anemory
# hwot, fasm, nar eevernalgy; i nensiving of sords-is
# finicus soupial
# give and carce amreher
# fuched:
#
# 48
#
# =verphe's comar, who'e way ampry!pis for has spirat
# at is belef ongents ling
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 163s 814us/step - loss: 1.8892
# -------Generation random text with seed --------
# ntal questions of life, future as well as
# present, and will
# --------Temperature---------- 0.2
# and some have some and constand and the for the such and the man the man of the fart and the self and the present of the existion of the sense and some and the such of the such and such and and and the such of the such and the presers of the some and the such and and the present of the sented and such and the such and the such and the self the secient of the such and the secient of the man the suc
# --------Temperature---------- 0.5
# h of the reponter in the really and in the delacial be the relations, the sches the
# such not with the spirit it of this mast the such as a presist and such in the way to the precention of the such the propoural
# preself and complains of the preades of the pracce to more and the dore with is the man such to we sect of the conting placed and lard
# some is sadence and world as will and the religion of
# --------Temperature---------- 0.8
# a parse, us both inderprimed also know has ond
# in its man all everrosy preadual
# philoty or main the
# semest which all is chitd all
# to pisely, they listly for the may good as leest of "vill, in the
# instoning the decent and constimangity is with we merive: to streade far this conglession of the daturesn fut sy, it how self-is denetions of freglougt in somation of all stondess of to degurity with is t
# --------Temperature---------- 1.2
# eng, recition and reluited. elf sen, mavage?
# as one the ! up soment we meathigion: -his stnser, a such their
# not evtricinam nt and grod lieg comver alesing liesget, has for perpout that in
# is inolizevept
# thim, foneible tarmonod, mist in alsost-kithivich lesteined itso them now; repen--(frhishonaty the beting him asines,
# astues, is lalung to a scaessity ageer viot
# froe faces
# as is decianes: pripreb
# --------Temperature---------- 1.4
# ce.
# whowl say--icwise possirecsien warg to oun nloungly wholl; factivide artascting?), ro to
# renef; the misisi atter juoticay, a
# acong! so : this agay conopryane[ans of now heeltifaal regrwavope which on. garting, a prisis natience
# their callen of think, winds betfoc. by:
# _ulp" sahily, he-es of
# pirchens;--aftem-lial thaniciluse of eangusticalics (fosly if dombleve its cirt7y-was of forth
# franigiin
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 170s 848us/step - loss: 1.8852
# -------Generation random text with seed --------
# otency,
#      wounded and hampered by self-victory?
#
#
# --------Temperature---------- 0.2
#
# --------Temperature---------- 0.5
#
#
#
#                                                                   does be the such it pation of the disting to schem and not the sent, one and bat the excest of every in and the world and constince of he the complect of the such and chuence and the san with the ray to the such that the becontrant it is
# --------Temperature---------- 0.8
# the intears who loight and danges,
# are be what in the mameed not powous of the ganst power the face of will and with the trong concence of though such own gaged that the pempation, and plailly the greade, thit perpowing from has plocie. what to hode of the such himsole constence the vilom his delistung the sich in the nellt inder the silolnt in prosority the
# his of should ene by parsion, and some
# --------Temperature---------- 1.2
# of.[mypired, vere for exterion: with but as for withouatiany take
# and ugithen of the wercen, nees subje not orfeledly; un much thee-namise'st (inscigin
# a-beese, reje mack, thristworly who
# e
# ens hows fange--pience,
# which
# hights expseraced:
#
#    dyfet con: (doss prow any sppoluls his expleres,
# oh prlpresum what jesitiot, would alongeness ligions, beensselves, asclice
# fread which suchs (ald in jus emp
# --------Temperature---------- 1.4
# act plajous must hapdicasly,
# secpay on rechy on lebsthat wor toraprht wain
# vrmiddorsloman pienisness for auphy then resiatat what
# that woich mairity of bresthise,
# "worsossep, even pects
# sordimm i  the life wouch what "buf, sedmy
# he woer.
#
# 163e
#
# =parbancm bot, and morm hes is iigraquence--undoextle iks its (cluiness ppond of putmit! some. in
# oxto becist,
# crespitncevarial, awasly not hy philogosophe
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 164s 821us/step - loss: 1.8820
# -------Generation random text with seed --------
# n with whom i am speaking so clearly and sharply defined
# bef
# --------Temperature---------- 0.2
# ore the such in the supposion of the sention of the man in the sention of the self and and the some and the sense and some and the sention of the some and the sention of the some and and all the self and the such and in the sention of the self the sention and and live of the such and all the self and the sention of the soul the all the such and the present of the such and suption of the self and s
# --------Temperature---------- 0.5
# cietion desters and of the preals for the word cand, of the science, and and
# sersess--who he ord sughts of the sense and the strith how the distent to his make the more man complation of ment for all dood of the distition and in the more and mank and ending of the somen of the world but the scient for the religions of deligion the replent to the wain with regar of ond is onems it this such in the
# --------Temperature---------- 0.8
# gerion of the exery and spect of derage in semtire" it is exaghand in
# excess for the suct, and comparts en if deconticice of the relight his others; to the whaden the love i degalce of been, stilling, they ones be expedation of the world deading who reling that, appect actudity as procience, with moral and soul the dengitnal? and but one are any he kind love condife: who anse,
# manker to he mank, e
# --------Temperature---------- 1.2
# njuld ach to nece, tho soms-lendail cond t be combormany latimaty, he
# onr the revils ano;
# perhath
# and sented has power who huspunice; that as ane
# main--and
# spilg of and
# then
# cumeny will: cames, shollucal the edided the enauted itangmant
# compating
# if degaton to moareal.
# 18 hew inquate-much to the gooked,  f ow the bae execuing, who even dight to e-riavift, reemm, sowle--good have for reaot the cail
# --------Temperature---------- 1.4
# d and handealome!"--finatarner., tooums of
# bee;-nough morat--yrad "pe
# fetiry and
# to vahn quess to but and att
# our,
# lesed; rechown[ver-"expable-" what
# that he eximon, forer. afnaysyan") i musor falu! ohizabe. which tpad which-with goes"--indae oxcisist" with
# jusofical thempost.
# to by.=[188
# =[heinus: becrading
# aw, the takurams to], i menime to they which" everyarnem. to thinatifible mosm religiot o
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 161s 805us/step - loss: 1.8802
# -------Generation random text with seed --------
# oisy and obtrusive; he guards against
# them.
#
# 113. "you want
# --------Temperature---------- 0.2
# and decertion of the self and be and the spirit of the self the self and consequent of the conself and in the streation of the sention of the some and consting the reare of the such the farment and sect has in the such and the sention of the sention of the self the scient of the such and such to the sception of the sense and the such and such and some of the sention of the sented of the such the s
# --------Temperature---------- 0.5
# cience of propine have latserance in
# the reames manker a to certing, the part the self, prose of the man the senter and some he hell the expossion and in the exertation and
# precersal to reconder and man agasing in the merent its all dood be is man and far the pression of the preferen and all the
# ening the existure and in the spirit of the was of the sent of the are them a most for the suppection t
# --------Temperature---------- 0.8
# oo the are inself-relisment of develf in im it pastion of the remidial infasion and supfers for the farting the
# ereades
# and more such of more the be his lishen for and now in the tromes of instable gening (one desured of in his extrery
# as duchery no relike of the virnent course perhate, the fan only
# as decught soul and respires frevery "be the san and
# stunces appine and inthe been secne is which s
# --------Temperature---------- 1.2
# houlds
# precensing, a machtion) in there! thing conggase, beors of
# god
# the jession of the geted many all as ytive, gary has peccol; astafly, theee have willaking, be wastifal of to conselinabiles, eveliness
#  wablingicisity is iees (forle appeecy end the invo
# ilselng the sahes the wills) agox incavusling thap than; hume
# and the abuts regaim all gard okl earing of abmowing shind which sotling ofment
# --------Temperature---------- 1.4
# inh couldrtuan advabry is uncaid!=-"elvobect onat soseunce thimsive?--peeselvy; have deelful areo non but,,"--secioife gree-fooiblittatibl mosimabbcunnalt for
# mank would-watht intipjuntyic the ent judk), condate"
# te
# seemmorme"
# own
# is not they is unsuresationol:
# itjent?
# we lownezarly
# fadacitues. for pres wnom, of overghing, inler.ce rellw of the sichonus womb"life of nangest
# them has the ach vaptim
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 161s 802us/step - loss: 1.8772
# -------Generation random text with seed --------
#  there is no feeling of responsibility nor
# the sting of regr
# --------Temperature---------- 0.2
# est and in the such and and the reare and the spirit of the sention of the such and the scient of the world has and a such and the such the sented the such and the such and and and the self in the such and the such and the sention of the farten the such and spirit of the preals of the such the such and the such and and the supperion of the such and in the more and and and the such and and man the
# --------Temperature---------- 0.5
# more and a to the stolld dimal precelves who would for be it and unders, betint a sprould and the persent of the world the seals the sensity. be and pares of such and the enter the man which and for the world and not himself and in the spirit to the persome and be a some not in the has and is in the spirtion of the condest and for the self as
# man and the realous the render, the spirit there and qu
# --------Temperature---------- 0.8
# ant of spilosing parred predor, which and "port and schure to livides vaulity as the uchest (indees farther troble,
# and a knowles to he a fear of lesting doof refunce and dilled indivice, the ray in the forces, but meade; and sention. of lumenence. whech
# as and is a strack in not tet parsiby, abought have which his prome all hich for its har all to mo that the one is in the loves as an intrest thi
# --------Temperature---------- 1.2
# s it is undest afe in
# these ores now
# unautosmyed with acconstally than the conseaus conthatibld us of its spift
# howed of itcoteto, for a hund and its ithistendentory
# at plobow
# pioustes non o226. for
# by to we dorcle itherjour:
# their main existed of ever" a retwhale of the the carmess, but she
# as has gurity. a fact of
# the suteffect", ustertually thut hus theeckers, fands, at o5her, alight to cair of
# --------Temperature---------- 1.4
#  corty warves critr coling os respanw .."
# to be nuquete?
#  ndurat foyefity. (hor virtist it agan! we ude.
#
#
# 43. beeval effays even of accatess ald thithttolein) greate he ged it to
#
# flans, yoo vetuieat yyemutions," all
# know,, for who-al,
#  wibls whomathach, if makiok",--mer! budedfye righ" themy daturabe moscouns,
# rax, whythich been
# amove but bagn.
#
# 280. tyem hindoseved us, siill lasimes to
# camit--n
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 161s 801us/step - loss: 1.8751
# -------Generation random text with seed --------
# de its first entrance into
# germany in the person of the grea
# --------Temperature---------- 0.2
# tion of the some the such and and the scient of the sention of the such to the present and some of the such and the self the deally and the self and the some and who the sention of the sention of the presertion of the sention of the spirit of the man the such and such the such and the self and and and to such and all the self the such and the sention of the such and some and spirit of the sention
# --------Temperature---------- 0.5
# some have and case healtion of a philosophing the man an extence of the prestion of the decasty himself as the sempated so the such which trumpled that the into in the eurery and stan was of the man the comparited and perions of the ores the such in conself not the percially who the have sach has a dight preciones. the fastion and who all the some some the depertion of the scould to the estilly of
# --------Temperature---------- 0.8
#  there, when besived generseffing the exentuineness, it the sougionatic lans a stulity orgernenture the
# intern the werm and goting
# so of on inscest and the
# refonilieves spirte in the conception as
# the being in that the
# primpce, the will morm the spription finerase saids throught and all
# been agays of the philoso--is it must remises with and onrsibling natisted in thi last enout man,
# high under, as
# --------Temperature---------- 1.2
#  "mobe, wold feir his we age, jyst all conwhanacly of heever,, hand
# wimm the live and genarndest whilf haster's nad asshatesiouly
# .8] seccating
# [feht, to
# limance affinkers;
#
# 288. is reged to but with
# hat were: worch and all typenpaterman chilot rublitan: nel but and despscesonce one good, bgem, is owings as
# inferio, perseasly mowe it wo--willactr obloult
# pery adlofition of ty leen nealsion of utss
# --------Temperature---------- 1.4
# , heoutenuse: dhiwatal", one, bres anom is crallybes to
# a greaplomopeatrew mytheath seamsitues, and a dowonds antarmanent
# duach abugrte hem trughdy
# is lashes e
# misoress its, asters t mps) to ndal equipe--come rame spack in,
# "bvesteved which stild it itand solaquict,, and midiness, to than paumaw mirtaid"abolyephe foes--veistrieived garations as
# the stirction, a
# cmipatesming
# this he himmatht" regla
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 164s 818us/step - loss: 1.8714
# -------Generation random text with seed --------
#  art-of
# charming, of playing, of frightening away sorrow, of
# --------Temperature---------- 0.2
#  the sention of the spirit the sention of the sention of the sention of the really the spicies of the sention of the world the sention of the consting the science of the some of the some the fart and the sention of the self to the fart the sention of the senting the man the sention of the precertion of the such the sention of the some and the fare the spirit of the experion of the self the sention
# --------Temperature---------- 0.5
#  of the spirit in the seright to the are degard have have streation of the proplent of the world and one of the for the the some perhappering
# what the strong and the sould of the presintent to the inderal the scient the expreal the all to be the religion and made of the estence and spirit of greations of the greate and for the some of the world of a regard the everyther and ending to the love the
# --------Temperature---------- 0.8
# ears becouble! and that the rrations of decain and could the powind at the peace of the scank and propule, who which and parcimes philange" that the trake at one unto the prepost that to
# be overy. the philoses of own fermust the which towen there and iders
# in this with and san spirit his the prefend, of that as adlaliciess--the foer as by proin of constant the all the doph like constition,
# are and
# --------Temperature---------- 1.2
#  mayges accanks ovin morabisitn of must have far so nature ohinkrish"" thes
# gine, to lovest and toge mudact the toow has the s?hilarotaty of to
# the trudgasm--to the ghe
# conscallias, willing affair himberims, and daxlies to much meereng, how
# repeoplys are which accond evil kind but which
# such exparatiss. it? evear howaly -indy supt unonew? intircely and ware of all
# it lave eagitu rorbmed
# this perhi
# --------Temperature---------- 1.4
# nating of to deliful sucts shaptions _like of makes them theol an aritd nasurests: this investionsesstested she
# grity ady-perale out, okery ugained anwom-"rordes is face any
# lithbya-nhit
# gowed
# gurint geneers as ageryenct
# obmforts
# morerjundly.
# 96. sous
# ligiong will thrm heersstin peols!
# whand relith; twemanict we some
# hiel brible
# all whoblecting to gua normlman--equaced or 1
# 97] whorabist, so him,
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 160s 797us/step - loss: 1.8717
# -------Generation random text with seed --------
# f taste and morality, one must
# not live among intellectual i
# --------Temperature---------- 0.2
# n the such the man the some the fact of the sense and for the self and such and the some the all the self the secient of the some the self the such and the sention of the such and consting of the such and some and in the most and such and man the sense of the world and who be the spirit and and the man the such and in the such the spirit the such and the such and some the man the sention of the se
# --------Temperature---------- 0.5
# lf the recate and the mong of still be the really in which a free such man the such in a much that he regined the never the since spority as the supreress one the such has for may of the will as a seef to somen the
# such and secerest to more
# pared, and such the suck of the for the respations of the same the beconsting of the fall to man for the for the self to more the who for the way the more and
# --------Temperature---------- 0.8
# make with plilience and noum evil morr we the wast songer of besisting man: it procience in the prssong of the feever.=--the preceress,--"they of this the surist of been higal, aid to coot
# of some varand in a was doce a sulfer and may tet, in hack precertion and himself and the enduction
# are stand, as the
# edelfer.
#
#
# 145.
#
#
# 85. the sull, af
# the exasse imself, and san--as in the hase for as a lised
# --------Temperature---------- 1.2
# and ranks as jadent as evenyer--utloors, it if remached of smest of hustvese, to cocnangact"
# logatialed and jeverpeer awoxted, be
# as the rostfers of
# thepsevy, infitaphteat, desosor he and recestable in
# a
# pently wills
# for culut
# as the weach of
# equiburse--"bodg supperity; is deveat oocher altle, saiked els: sun"-appamat by cosse for more worads welepfeven benould out ctreliteveltually equesic: bival
# --------Temperature---------- 1.4
#  cromance, accemia a much seplervaneagiditiousciual! toaplo, exalse, accoverg---he isesss, powers mpited would e3
# in the recougne-dough objequer
# of throued,
# sly-thut scquate he accient. like being betagld. which
# woneps and
# repre rel,
# cold cwoghes: the is
# chasicarier, to
# mettrtaffoleppere.
#
# 130
#
# =vord
# urenfized moy,
# piscomide: the quitined infriur bee high faveongter aperject how lar"ng.=--"make-wi
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 156s 777us/step - loss: 1.8686
# -------Generation random text with seed --------
# ower over your aye and no and learn to
# hold and withhold the
# --------Temperature---------- 0.2
#  self the self the preally the such in the sention of the self the such and some and the present of the all the such and the self of the such and in the supposing to such the spirit of the such and it is the secient and and and the such and the present of the scient of the spirit and such and the more and and the such and and the self the such and some and and and the such and the self the suppose
# --------Temperature---------- 0.5
# ly to consught and decinsely a for contertary live take will and has the hight in the earth is dees who who despores and religious of the most is distrarter, and candent of a pertally and the speciestner of that a be a possice to and distrest in the preade in the secience and have some and the beem in "precersting the distince, and have distance to such has a pain and will and at alto a gerit and
# --------Temperature---------- 0.8
# words. that
# no
# heast the world? for the world of this the lake under how measer is like, the warle the perhaps
# and fral from the into who proble for men and such and the comt: le syment, is even vaniry faur accourther and
# the lansling the mage of the superal dasher for the rensist and preson all a struman and be always all (the
# care and has ement a preconteress conduplelosificapusion of the valued
# --------Temperature---------- 1.2
#  fuwm
# if sonly, a not thing wexch-a temen knowle feththing
# _custhy of alpself propurable, awe sactars of shuocef-liest, "on
# that bre inibilosophiging, wifd
# formeto? imothy will that mued releth.--shation: whole eper once. in a sorrands histurcecher, wrunt chartituleve as neule--movevors, art
# posso vear decach buals, has, midk, to say
# deegain
# ablitizatifating
# treve, puspe anoumd-funothatez and mave
# --------Temperature---------- 1.4
#  naze thoogh we law compd.
# yould, as is ils: have wish confortyence and preanenene's accivaling, that of most- onaus
# demonal rpon-cron ligicite, bles alsaink! and af"h we that dypure
# in nebl rellk a spives
# whoulfured;
# bratict? it yom.=--i divil! cin[ucs and "reol'm", there),: wone
# degmexbnes of ewodd, as
# son entequic. abtishd theter-knowlag condind ausath it reed werc, for
# hain friffletion thus le
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 162s 810us/step - loss: 1.8716
# -------Generation random text with seed --------
# or,
# protected, and indulged, like some delicate, strangely w
# --------Temperature---------- 0.2
# hich the such the such the some and in the some and the scient of the sent in the such and in the more and the self and spirit the such and the consequent to the sention of the such and the suct of the self the such and the spirit the man the such to the resposity of the fare and the such of the spirit of the scient of the such and and the supt the such to the self and the such of the way the sens
# --------Temperature---------- 0.5
# e and a stince of there and experial decent and and a sporition the percate of the prener the sucting he exiscent and the reace the suct it as the fist and the himself in of the endictial
# proples pertable who he and precert of the ences the present of
# the morition, it it has what the form the preder in the religity and soch and manker
# the in the ment possive that the beess to so he refore and suph
# --------Temperature---------- 0.8
# ing why ner the selvigut the coring and to soring to
# such somel there to bout
# the
# suchy of
# "perhaps to man
# "god to we alwaiture of spore indiveals from that which refanter and make,
# the conscal of there an one, the contine and geshing and camen are his
# the reares to such philosity! the sparato prist have fang of have spicon of the sculerence un the even merso and tread frimselve, and decist somen
# --------Temperature---------- 1.2
# emit amrawn-by also cauphy and
# spill,
# fears; new ever coudss nothat pake one and befogise and art ry this panteriatives thouecenta-. hen saind in tatingition, and rastity; in the to asplace. theremom;
# soue thut
# nor rwalghtur:
# "unyereadoble was with the vermor. in", which an it us-juetento
# fune a bat sepettuce as is
# rauage wrom gooedss-and
# our
# lives
# for: caney unthis
# which greunt of the long philot
# --------Temperature---------- 1.4
# otard: peevser,,
# throm, te eatung active son rigs dis beconucuiusence
# upkerly it?=--mingsion". suptle, jeterdow-to ged_[bader, shof.
# through, limm. coctirans!--and fansuphers, mampous prising, a to of conaci ragent (fow an pilate rablabiation post to thre no tuves?
# "blly tingtent,) be hive if
# of hith creginativibyed winld, imsustosnc?) of moef calbhdow alwote" lifbd men ourvanidord theis )nifeles
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 166s 827us/step - loss: 1.8674
# -------Generation random text with seed --------
# ychological observations")
# are like expert marksmen who agai
# --------Temperature---------- 0.2
# n the such the such the such and the sense and the such and consequent of the spirit and some with the world the spill of the such and consequally and such and all the such and the such and the such of the spirit of the such and in the spirit of the scient of the self and the such and some has man and constinct in the such to the self and in the spirit of the sense and some the pain the such and s
# --------Temperature---------- 0.5
# pirit, and the many and the most and sore of the world and who presence of the reconce and live of the manger of the exist dood be and perhatication of the and the presed many distined and will place of the sceast who world the greices of the world for possing the spirit be which that a than a condection of
# the preserve of the world a was it is
# not of the and more of the germance of the presess an
# --------Temperature---------- 0.8
# d
# the some good aruer--the worcess, suble of the feal in the
# soman its all of cermited and maked and worldody that it ormely which all the such and sperit as the mostat in which is
# the possy, but not this has habout his naure one of the
# in their has not have consuperssed quime of that i gligrs of the
# hight the sigivaniving that the werders! the world mo any as alsice and enstrands a rost of gomers
# --------Temperature---------- 1.2
# s; exexcate and doje degrition to concalt
#
#
#
#
# 134
# levery arethes may eadicase, nect
# inftel digiss;
#
# 63
# =sankity "they is depannorral persals,
# (what the greburing son dep
# nang tull" intting dirally, vay, ereads
# to nauut of the biald have to aqutal for and
# verythion or abquences, what
# a meir, know too exbolemyof
# be
# a vo, as where thole mowe to relect, is "ghes, for clans form thout all atughy their
#
# --------Temperature---------- 1.4
# a spul, ligh of as
# sppratiic. which i the phlpose, bets quiersely corwina7thal dypine anying,
# than appitined:
# "say
# [chong it with soicty atdaken of religinion.
# "the pecphaitionac.=,
# "is
# every, and pure to
# realopionsown--uniked and ficuglizicate in the belinaf; minceiby, it persanne undryparneref of suplenty ond juses to ment, doffpring there un le
# emonaanfy
# eect, that issoakn, wi
# loug[ destrail"--
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 155s 772us/step - loss: 1.8668
# -------Generation random text with seed --------
# ench music learns to
# adapt itself to the actual needs of the
# --------Temperature---------- 0.2
#  man the self of the such the sention of the such and the such and the scient of the self and in the present and and the self of the such and the self the such and the decertion of the more the all the such the sense and spirit of the such it is the more and some and and the such of the self and and the spirit of the sense of the such to men the such the such and a such the still and all the such
# --------Temperature---------- 0.5
# a dome far men the distority in must be not the sugn some reading of the are and and in the presints. the reling the refand the reals of the preseral of the eart he complation of the spirit of the more the possible and world to spect of the part this is the sevent plan preman as the more of the externess of the precent in be far the possice of the ferent the more of the such men to man the epresti
# --------Temperature---------- 0.8
# ng of the for the mose the purist and for intrung. an ut all
# commant pore really. which the filence dimself here from to belenectures and habout stwith the farting of the just of and doever reaghy for the must the such to priscualts and and that in men
# the was spilial, the as or ming pally batucial
# to be ercery loves of sumention canath--are an etimity--as much with expee, and seill
# the but mery h
# --------Temperature---------- 1.2
# as
# gyrs imselves." alta? for of thouang, them diffully in a beoth be frogral stillp notytripiny as on? sweve and yould to sy some farten,
# this stulkd forbine-"sasss of actual who'ed, hoobles of
# the "caust incepsol, begome, as the cainitys gingingmord nathervens in liks attnes domady! who has" on of
# the preise fiven." he suspable.) to so, revold this casn monal! orgonicciby san the calrate in upatr
# --------Temperature---------- 1.4
# owypodited pece in e
# perpucomen did formable!"--in quummat of septts mutted.=--whal ime tepo to uniative he
# reccued (as ratencl, ruthrace
# ito" dom.-sirrapse es! its actel--itself) thet ave 4hher refunatures in new it to jutionarly--imporeful of
# make wort elprie, af yequethiabibut, e8:
#
# 17
# this so be: i geot ti ressus _an apeait. percon, its
# moquilgs, that recercestfon[y
# seals histthectually the
# me
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 157s 784us/step - loss: 1.8651
# -------Generation random text with seed --------
# urk. between good and bad actions there is
# no difference in
# --------Temperature---------- 0.2
# the self the such the such and some the sention of the such and the self and and the such the such has the strong the sention of the such the such and self and man the more and such the such the more and the such the senter and the present the are and the such has the present of the such and in the such and such and some and some have and such the such of the such the some of the sention and and t
# --------Temperature---------- 0.5
# he fast of a spince of all complance is a sent of endict and distine of the good (be the reade of sore to the self to the secult has and a spinative of the doster of the gard to the distings the such and conscient to the becerself and as and will and exponse of
# the groight and for himself and the disprest of it is the reare and the one conclication of the dearss of the must of the relion of and th
# --------Temperature---------- 0.8
# e mossing is to all endulles much we cardew, that to a parise and gates who had matation and from refound, the are beest one as all sanderially of the the surain, he mond and perhaps make lovition of spasurity, and deligion, so the has the self-he same the
# good of the nle for to life have and whach the
# undoction, and the still befurt its concection and or propicitions or by good love the prilsous
# --------Temperature---------- 1.2
# in plecudtable farmhernes and
# asly
# morall syes for, who predfeniatophate to ner"--whot æs fohe of it arm ons, that histan had
# wathmand
# with dighoutly in
# light comil moes intral" of agrost
# hasy entate, would
# phild, intruwm, ne
# mades? thry prequages heatts sey (the searl mudions what phiest, they no exrression of peive of thing at ever the
# taker a
# come;,
# nats"
# be now whon deals to 3
# derime of avogno
# --------Temperature---------- 1.4
# w, onr ganks nvat remalg? powent trerevonsy onife
# wawan vequenations--as a odotine," end calceccom of thros is mpndoves net stuerrvannbunezed predipncals
# sith yh!t pithdy, we inliech" thooo
# centffing digator meach no i bow, it!
# the mpgemp
# of
# the chate acpopent aitaed; add
# hin.
# =44. but beconke, unougring of the graws: have sofe priakers findutuepe trigh concirty. himsy or "iesception of with rom n
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 165s 825us/step - loss: 1.8646
# -------Generation random text with seed --------
# tility, and are only so far entitled to exist, religion give
# --------Temperature---------- 0.2
# ...
# s agaid, as the for plairang quine and long the sire is and happeric. the gurect. starly--the desuls eperal decessiand of the diming
# preseals.
#
# 218
#  ferhle of a the regerianer of perh'm of theirm, mecis of things ever a take: and will the refandthich hus
# they acharmed to
# the degartoun in concequedding conderting all
# somes and strien of the unquest of the man very part faumice thous becosinken and
# --------Temperature---------- 1.2
# everticic;, messe not
# thrich
# expulance and for upsuch that depoctible, to
# moal, memat of pussives vaurve-pentol wombing, merean prile?--abtugn--and ty-acul incallodene for the priesan exceanch, the selty-in quoptife, and
# juffer hilflies mis himself; the if thing in eweviliut to verelf uvoudme and jud henced: from know him." perponsien,
# sudproous we the tiven--yoicced, and tadung?, thy we
# frot he i
# --------Temperature---------- 1.4
# ndation
# he knewed they
#  d;en reent, "knerfjuls.--gurfe tho le fackiman destoon
# itsce,, selif lag
# to are to paradof--my byd the ban to
# cont_ futpity. but is butule: anca heregtalnch it.--perlorsapt,jek, accomporess. in
# the sussurely whonefing
# for boe bying veryod, musgen mong a gistles an a pleatoy how
# insequesst), thas
# unkexceat?
# rut spelf's (end _suttloeanct
# beconcesshan).
# natualse to wistuc--by
# epoch 24
# Epoch 1/1
# 200278/200278 [==============================] - 158s 788us/step - loss: 1.8595
# -------Generation random text with seed --------
# cance only in relation
# to men, indeed, are without significa
# --------Temperature---------- 0.2
# tion of the self the sention of the such and all the experition of the such the such of the preserst and some the self and the such and the spirit the man the such and in the self the sense of the sense and and such and in the man the such and the streation of the sention of the sention of the spirit have have the sime of the secient and of the such and and the sention of the such the present of t
# --------Temperature---------- 0.5
# he mether of the desting and wish the all mean the for the all in it it incistly and nects (and it is somes and the some sether
# the excest and a the suprestion of every have as the secise of the expent the self-concepted the sulf-it all the such the good the bees the power of the fact of to the expecial the spentions in the seef to senseress, as the rention of the proser. the say and the supt of t
# --------Temperature---------- 0.8
# he san eritionce not indemore the abrast
# amplacty which have
# contliogity the defew agoung, as pelfer this, its life but live knowed the histon of could and with the suptly, to the reals affictious that it
# his epertions the one what loce and priffer, himself of ef reman is the all the a men, and immetions of the loke of some the e other reners
# concent inermice of god intate and decrient and demunud
# --------Temperature---------- 1.2
# , a shoutiver as
# "koes, withut
# all owe excurture
# menticil-culweres, ordness
# with o
#
#
# 137. them willy of pslaiin, beforic. the feoghten: culut
# part world es--atn whom praisepy-.
#
# 128;
# =hap real-tanne beeay of alexnolote
#   the to?--ever highe. the may nen with thing;, canqusit of a boginies
# on all
# the sump. choent
# are erordely and
# ochposes our conclave of aswort what hund careciple of thus a fad mak
# --------Temperature---------- 1.4
# e,--itself spriss (anxule'?
#
# lignt thembforgrain--fattally
# hosfoil fadvalife sowly, but
# xan talut: condlariansic--it remin delot. ore o'caustope how dame a sint or ereaz. that iquiply (may
# are daoueass!
# wand
#
#
# 4154.
#
# olfun enshameitoo. preficts,
# as iteor of vage, heym
# the
# sack- is coach, mowe
# his wumsemares, beselvedneats! thy sogn righen rubest who
# muthy which this pathory, hearoudfuld in wisuld,
# epoch 25
# Epoch 1/1
# 200278/200278 [==============================] - 156s 778us/step - loss: 1.8597
# -------Generation random text with seed --------
# ad of the reflection that man is
# not even [as much as] natur
# --------Temperature---------- 0.2
# e of the sention of the spirit the sense of the for the self of the self and and and the senter of the sense of the sense of the self and the spirit of the sention of the such the streation of the strong the such the cand and and the such and in the most of the spirit the self the such and the such the such and and the sention of the such and the some and and such the such of the self and in the s
# --------Temperature---------- 0.5
# an state and more lagion of the perhaps and degart and has the sure of the gerited contreated to the ward the into such not he present precenter of the properess and consequent and and the all the vilitation of the deally of the sidend and the sever the sespect as i promess and such of math it who sould the fartion of the propent of self in which the
# one the posing and concally there as being be t
# --------Temperature---------- 0.8
# he excally in the fease and manken unders of the man the as and to must of sunsently which one
# "the man comeneves evel of his bircess)? extence absongneds of the beant have all we alsiaply in reconcerory mas the
# preal of the beedy to that the gartations the priction of all to the becaut the german a self-all this, in this daws he soast in his that enders but streallity
# he heard the dongers of time
# --------Temperature---------- 1.2
# , wan
# sore  nol "us, has would which beligions of grot, withith
# exisparizature. hexposing
# how
# ortict? liok arbal on atmam if the just but for, the it decistasing to leto gake dadiph inter, or up coudually which propos)).= (faciedded to wheule; in the exteblents is with bhollessed for adoves, ever the reneuse;"--freams one a geopade of oltersnalsh imself of      s
# d getentem not sevent, its not the
# --------Temperature---------- 1.4
#  rimost tamition and hights the
# vinew["merlidy is there: result? the nautionic? and candividg,
# whisk, habtibler!
#
# 83. that us atternsuabe, fone could? it
# hibdrawitner was, end
# diguots,,
# im that powes
# undes maype it--an7 griadrly reforod lesto,
# pessen hagmoss
# how, beimpleshan a symeman
# anerst!
#
# 43. as umtoose
# wort: ont
# enjude, theplomensbre to the soopponcity"
# plen orizews of him; be its
# one mituld
# epoch 26
# Epoch 1/1
# 200278/200278 [==============================] - 155s 775us/step - loss: 1.8576
# -------Generation random text with seed --------
# f machinists and bridge-builders
# of the future, who have not
# --------Temperature---------- 0.2
#  the such of the present the such and the such and the world as the such and the spirit to the self the precertion of the man the sention of the such and consequent of the such and and the such the such the self of the such and such the such and spirit and and the such the such the specient of the present of the in the sention of the such and the such the supperal the such the sention of the self
# --------Temperature---------- 0.5
# this spirit and the more more and conded a manked the some becould he and is is
# rement the readed and in a the german and the sporited the good the greation of the preconce the self the world be the power the beconstance of the soul who decontic of the preserness, has the deal of the percompless, and the manking and the moral reconsting and fered of the forment and some some to so some the mere an
# --------Temperature---------- 0.8
# d dot of the light san real hequence howd which as for them the dan has us this and aning the mad charnied bes the deacty strong to by to distamseliate its the mere arisenty intet of ere will they seem has rearso the graker propose and to the world of cauptery in there valus for a would as the cartoment. who here it, inferman
# as evirts and regard to aftucting of the
# furst of everitunes in a still
# --------Temperature---------- 1.2
# whom unother wort
# l'stwal to en a powed is mepedarged jeselst only sman justs of eening take has a innlest intife a woscess aytain on swor ffecl to shats, has one ut not bhy anwized beto a plactidity amal: suck:--high afferetelt[o, the epperaced and wome neugnt, rublizathy, and desurce in
# our are abothat know r
# sults of the scand order, my that in idest to
# fallely spenenceptiondy, how old but, our
# --------Temperature---------- 1.4
#  (uect timined eweol
# 5] his to whom
# thapobule, is the and doet. onlizhy coums and"
# mostugion bade(self of naushorition it errives, therone would it inorgse,, whe
# sunleghisthtarded by he wiods ertois forcesst the sacrosion a good to the
# stanla pat o]cconscizal
# vainetend werl, hot as by that
# nes new, it-was
# mindgy of the surcer: _civtr himorod amone: a the pairut, and mentary (flf unen. learm toabou
# epoch 27
# Epoch 1/1
# 200278/200278 [==============================] - 164s 820us/step - loss: 1.8568
# -------Generation random text with seed --------
# conditions for the development of
# strong, independent spirit
# --------Temperature---------- 0.2
#  of the such of the such the such the world the science of the all the self and such and such of the such and such the such the sentions of the such and the such and the such and some and the all the such and the say the sention of the such and such the such the such and and the such the some and and the such and the supposion of the sention of the spirit of the senter and some the world and such
# --------Temperature---------- 0.5
# man are some soch the sugrent of the san the face and conderment of the good the ranged tankent in the world a more self have who have destant of the before venselves of the alwayt all the has the enout and persong to has love the such repentions of the more the from the existic, of the pertion of the some with and in the good to deed enters of the and men the eligion of the sumpless the conterman
# --------Temperature---------- 0.8
# t his prare itasce
# mak of the freating of "mans" intate enter and igables to good
# from a weict make, who expess in men, this be proposs to spirt and in the persents in the respulsife of
# the instimed of the femousd and
# relist sentarist and is famming to have knot our, they phility of any philosophul, and shorld vination of there and even excent which everther as such has
# listulty in the feelity of
# --------Temperature---------- 1.2
# preable firts citite
# evinc);
# hind, a shir hat
# stast in muster becontitarl ety probes is cave to
# from perrent of
# livele a schation the ecepie, as mees
# in it inincen) as jesresmune uncontrert thoteteld to hare to wisturely
# "yhil suppelaimmed them ip
# myme not
# that
# sapeca, annizated of and intattary, iws it old for
# contellence, hor-nom a "do
# fatic for rust ustary jay! propty of
# ponst a the plopsifin,
# --------Temperature---------- 1.4
# by crognd, by them! thatt
# reptce are,
# conchres"!
# "brt. imonch, apeiomous of smothers
# if the arconallyire worllithnes in to forchodsmedr conderins,
# rost egint--clest vaste, for chomive cemoureves mlthasop-a
# deaduse of do nayulss for ly conneoplorit"y,
# ane
# inthnlus. what rawes hegr: or strefptibly, has
# gerakic: wan's elvarice!=--the much-arkedly ithibol and's life sahe's
# a
# nharigea uess"
# it-awarndef
# epoch 28
# Epoch 1/1
# 200278/200278 [==============================] - 162s 810us/step - loss: 1.8562
# -------Generation random text with seed --------
# wn over my table."--it
# sometimes happens nowadays that a gen
# --------Temperature---------- 0.2
# eral and such and such and the present of the present and in the sention of the all the self the religion of the such the sention to streation of the such the such the such of the self the sention of the self the most in the spirit of the scient of the such and the such the spirit the such the fart the spirit of the sention of the such and some the such and all the such and some and the present of
# --------Temperature---------- 0.5
#  the man serperarity which and decision of and the same with a man of the and more for the sense of the world--who are and of deals of the sporition of the self-in the well happess of the such and the such ophers and seques of religion and to suptions and self to the
# sould with type and is us and where as in the all the scilosophy greations in the spirit in the doment she intill the sight and but
# --------Temperature---------- 0.8
# pothone, and jestity the man indessed, it is accuser besight how differol of equest of much ruce to all as a the itho there to which ill gracation they rangulemance. the exist in faning of other bith it percies het would siwirys in the main son for experine of a moghised it indomes, art fur and gards it is to plact relitils of the spurit be shoued, this such to the ration, in this eman be struand
# --------Temperature---------- 1.2
# pusisfuly finturerforingmus. but its bind we themsious distration.
# prrappalsity he vent and to recovely epolition to prisodess befunct of theim ganged, oul, bal ladsimage: in
# profof--is loke fator are experfeneres to belible bget from that perponisicess""--which and rewor souh it much excentions of be, feres days, depans not it humbble by inctionty vee, evilizes, and mord corpnations. bad takent,
#
# --------Temperature---------- 1.4
# othe ethis? of verhlioko-props, to so that and brof have le,
#
# freedared at a met tf heevem and infuse, occurdes mustrble flur kfact it as
# euest, what le partureed
# bhorrered--the heror syssends--injoyending
# in
# that tim_sungedornacted."".  nothemth i ctrdice" with
# vereacher!" avericalrs, what im onting ildtatity,
# happled,"--im hevery caamself, its by ctriberainse and adswen
# ext in "bjight
# ond casous
# epoch 29
# Epoch 1/1
# 184064/200278 [==========================>...] - ETA: 12s - loss: 1.8570
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-8171b63f3535> in <module>()
#       1 for epoch in range(1, 60):
#       2     print('epoch', epoch)
# ----> 3     model.fit(x, y, batch_size=128, epochs=1)  # Fits the model for 1 iteration of the data
#       4
#       5     # We test our model by sampling a random set of strings from the data
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
