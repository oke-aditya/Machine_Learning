# %% [markdown]
# # Data Handling in RAPIDS

# %% [markdown]
# ## Installing Rapids

# %% [markdown]
# - Note again use NVIDIA T4 or P4 or P100 GPU only

# %%
# !nvidia-smi
# Out:
# Fri Mar 20 15:34:24 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install RAPIDS
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !bash rapidsai-csp-utils/colab/rapids-colab.sh

import sys, os

dist_package_index = sys.path.index('/usr/local/lib/python3.6/dist-packages')
sys.path = sys.path[:dist_package_index] + ['/usr/local/lib/python3.6/site-packages'] + sys.path[dist_package_index:]
sys.path
exec(open('rapidsai-csp-utils/colab/update_modules.py').read(), globals())
# Out:
# Cloning into 'rapidsai-csp-utils'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 44 (delta 9), reused 5 (delta 0), pack-reused 0
# Unpacking objects: 100% (44/44), done.
# PLEASE READ
# ********************************************************************************************************
# Colab Notebooks Migration Notice:
#
# We have changed the location of the Colab script to our new CSP utilties repo.
# We are also dropping support for versions below 0.11, as we are on 0.13 nightlies
#
# Not all Colab notebooks are updated (like personal Colabs) and/or are using outdated versions of RAPIDS,
# so we HIGHLY encourage users to update their scripts and Colab notebooks both with the new link AND with
# to the new API.  Otherwise, your code MAY BREAK
#
# This notice will disappear/be updated on our next release.
#
# Please enter in the box your desired RAPIDS version (ex: '0.11' or '0.12', between 0.11 to 0.13, without the quotes)
# and hit Enter. If you need stability, use 0.12. If you want bleeding edge, use our nightlies (0.13), but things can break.
# 0.12
# Please COMPARE the "SCRIPT TO COPY" with the code in the above cell.  If they are the same, just type any key.  If not, do steps 2-4.
#
# SCRIPT TO COPY:
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !bash rapidsai-csp-utils/colab/rapids-colab.sh
# import sys, os
# dist_package_index = sys.path.index('/usr/local/lib/python3.6/dist-packages')
# sys.path = sys.path[:dist_package_index] + ['/usr/local/lib/python3.6/site-packages'] + sys.path[dist_package_index:]
# sys.path
# exec(open('rapidsai-csp-utils/colab/update_modules.py').read(), globals())
# ********************************************************************************************************
# Do you have the above version of the script running in your cell? (Y/N).
# Please note: If you do not positively affirm with 'Y' or 'y', the script show you have to rectify that issue and then stop the RAPIDS install,
# without installing RAPIDS, but will still continue update some packages
# Y
# Continuing with RAPIDS install
# Checking for GPU type:
# ***********************************************************************
# Woo! Your instance has the right kind of GPU, a 'Tesla T4'!
# ***********************************************************************
#
# Removing conflicting packages, will replace with RAPIDS compatible versions
# Uninstalling xgboost-0.90:
#   Successfully uninstalled xgboost-0.90
# Uninstalling dask-2.12.0:
#   Successfully uninstalled dask-2.12.0
# Uninstalling distributed-1.25.3:
#   Successfully uninstalled distributed-1.25.3
# Installing conda
# --2020-03-20 15:35:01--  https://repo.continuum.io/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M   118MB/s    in 0.5s
#
# 2020-03-20 15:35:02 (118 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - openssl
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libgcc-ng-9.2.0            |       h24d8f2e_2         8.2 MB  conda-forge
#     zlib-1.2.11                |    h516909a_1006         105 KB  conda-forge
#     _openmp_mutex-4.5          |            0_gnu         435 KB  conda-forge
#     libffi-3.2.1               |    he1b5a44_1007          47 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     wheel-0.34.2               |             py_1          24 KB  conda-forge
#     pip-20.0.2                 |             py_2         1.0 MB  conda-forge
#     libstdcxx-ng-9.2.0         |       hdf63c60_2         4.5 MB  conda-forge
#     openssl-1.1.1e             |       h516909a_0         2.1 MB  conda-forge
#     xz-5.2.4                   |    h14c3975_1001         366 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     python-3.6.10              |h9d8adfe_1009_cpython        34.1 MB  conda-forge
#     sqlite-3.30.1              |       hcee41ef_0         2.0 MB  conda-forge
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     libgomp-9.2.0              |       h24d8f2e_2         816 KB  conda-forge
#     setuptools-46.0.0          |   py36h9f0ad1d_2         638 KB  conda-forge
#     ld_impl_linux-64-2.34      |       h53a641e_0         616 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     tk-8.6.10                  |       hed695b0_0         3.2 MB  conda-forge
#     ncurses-6.1                |    hf484d3e_1002         1.3 MB  conda-forge
#     readline-8.0               |       hf8c457e_0         441 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        60.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:    0.1-conda_forge   conda-forge
#     _openmp_mutex:    4.5-0_gnu         conda-forge
#     ld_impl_linux-64: 2.34-h53a641e_0   conda-forge
#     libgomp:          9.2.0-h24d8f2e_2  conda-forge
#     python_abi:       3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates:  2018.03.07-0                  --> 2019.11.28-hecc5488_0        conda-forge
#     certifi:          2018.4.16-py36_0              --> 2019.11.28-py36h9f0ad1d_1    conda-forge
#     libffi:           3.2.1-hd88cf55_4              --> 3.2.1-he1b5a44_1007          conda-forge
#     libgcc-ng:        7.2.0-hdf63c60_3              --> 9.2.0-h24d8f2e_2             conda-forge
#     libstdcxx-ng:     7.2.0-hdf63c60_3              --> 9.2.0-hdf63c60_2             conda-forge
#     ncurses:          6.1-hf484d3e_0                --> 6.1-hf484d3e_1002            conda-forge
#     openssl:          1.0.2o-h20670df_0             --> 1.1.1e-h516909a_0            conda-forge
#     pip:              10.0.1-py36_0                 --> 20.0.2-py_2                  conda-forge
#     python:           3.6.5-hc3d631a_2              --> 3.6.10-h9d8adfe_1009_cpython conda-forge
#     readline:         7.0-ha6073c6_4                --> 8.0-hf8c457e_0               conda-forge
#     setuptools:       39.2.0-py36_0                 --> 46.0.0-py36h9f0ad1d_2        conda-forge
#     sqlite:           3.23.1-he433501_0             --> 3.30.1-hcee41ef_0            conda-forge
#     tk:               8.6.7-hc745277_3              --> 8.6.10-hed695b0_0            conda-forge
#     wheel:            0.31.1-py36_0                 --> 0.34.2-py_1                  conda-forge
#     xz:               5.2.4-h14c3975_4              --> 5.2.4-h14c3975_1001          conda-forge
#     zlib:             1.2.11-ha838bed_2             --> 1.2.11-h516909a_1006         conda-forge
#
#
# Downloading and Extracting Packages
# libgcc-ng-9.2.0      |  8.2 MB | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
# zlib-1.2.11          |  105 KB | : 100% 1.0/1 [00:00<00:00, 20.18it/s]
# _openmp_mutex-4.5    |  435 KB | : 100% 1.0/1 [00:00<00:00, 12.64it/s]
# libffi-3.2.1         |   47 KB | : 100% 1.0/1 [00:00<00:00, 13.30it/s]
# python_abi-3.6       |    4 KB | : 100% 1.0/1 [00:00<00:00, 23.86it/s]
# wheel-0.34.2         |   24 KB | : 100% 1.0/1 [00:00<00:00, 22.21it/s]
# pip-20.0.2           |  1.0 MB | : 100% 1.0/1 [00:00<00:00,  3.32it/s]
# libstdcxx-ng-9.2.0   |  4.5 MB | : 100% 1.0/1 [00:00<00:00,  1.46it/s]
# openssl-1.1.1e       |  2.1 MB | : 100% 1.0/1 [00:00<00:00,  2.53it/s]
# xz-5.2.4             |  366 KB | : 100% 1.0/1 [00:00<00:00,  9.18it/s]
# certifi-2019.11.28   |  149 KB | : 100% 1.0/1 [00:00<00:00, 18.86it/s]
# python-3.6.10        | 34.1 MB | : 100% 1.0/1 [00:04<00:00,  4.71s/it]
# sqlite-3.30.1        |  2.0 MB | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# _libgcc_mutex-0.1    |    3 KB | : 100% 1.0/1 [00:00<00:00, 29.93it/s]
# libgomp-9.2.0        |  816 KB | : 100% 1.0/1 [00:00<00:00,  7.27it/s]
# setuptools-46.0.0    |  638 KB | : 100% 1.0/1 [00:00<00:00,  4.85it/s]
# ld_impl_linux-64-2.3 |  616 KB | : 100% 1.0/1 [00:00<00:00,  5.32it/s]
# ca-certificates-2019 |  145 KB | : 100% 1.0/1 [00:00<00:00, 18.02it/s]
# tk-8.6.10            |  3.2 MB | : 100% 1.0/1 [00:00<00:00,  1.42it/s]
# ncurses-6.1          |  1.3 MB | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
# readline-8.0         |  441 KB | : 100% 1.0/1 [00:00<00:00,  8.04it/s]
# done
# done
# done
# Installing RAPIDS 0.12 packages from the stable release channel
# Please standby, this will take a few minutes...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.0
#     - cudf=0.12
#     - cugraph
#     - cuml
#     - cuspatial
#     - dask-cudf
#     - gcsfs
#     - pynvml
#     - python=3.6
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.0.0                |   py36h9f0ad1d_0         6.9 MB  conda-forge
#     sortedcontainers-2.1.0     |             py_0          25 KB  conda-forge
#     cachetools-3.1.1           |             py_0          11 KB  conda-forge
#     poppler-0.67.0             |       h14e79db_8         8.9 MB  conda-forge
#     geotiff-1.5.1              |       h38872f0_8         279 KB  conda-forge
#     cudnn-7.6.0                |       cuda10.0_0       216.6 MB  nvidia
#     pyarrow-0.15.0             |   py36h8b68381_1         3.2 MB  conda-forge
#     xorg-libxext-1.3.4         |       h516909a_0          51 KB  conda-forge
#     pyparsing-2.4.6            |             py_0          59 KB  conda-forge
#     olefile-0.46               |             py_0          31 KB  conda-forge
#     libcblas-3.8.0             |      14_openblas          10 KB  conda-forge
#     libgfortran-ng-7.3.0       |       hdf63c60_5         1.7 MB  conda-forge
#     xorg-libxau-1.0.9          |       h14c3975_0          13 KB  conda-forge
#     uriparser-0.9.3            |       he1b5a44_1          49 KB  conda-forge
#     pillow-7.0.0               |   py36h8328e55_1         652 KB  conda-forge
#     packaging-20.1             |             py_0          31 KB  conda-forge
#     oauthlib-3.0.1             |             py_0          82 KB  conda-forge
#     nvstrings-0.12.0           |           py36_0         129 KB  rapidsai
#     cuml-0.12.0                |  cuda10.0_py36_0         9.1 MB  rapidsai
#     cfitsio-3.470              |       hb60a0a2_2         1.4 MB  conda-forge
#     libcurl-7.68.0             |       hda55be3_0         564 KB  conda-forge
#     rsa-4.0                    |             py_0          27 KB  conda-forge
#     pyjwt-1.7.1                |             py_0          17 KB  conda-forge
#     cudf-0.12.0                |           py36_0         9.9 MB  rapidsai
#     libxgboost-0.90.rapidsdev1 |       cuda10.0_1        32.8 MB  rapidsai/label/xgboost
#     numpy-1.18.1               |   py36h95a1406_0         5.2 MB  conda-forge
#     pyyaml-5.1.2               |   py36h516909a_0         184 KB  conda-forge
#     ucx-py-0.12.0+g9d06c3a     |           py36_0         270 KB  rapidsai
#     libiconv-1.15              |    h516909a_1006         2.0 MB  conda-forge
#     libtiff-4.1.0              |       hfc65ed5_0         595 KB  conda-forge
#     dask-cudf-0.12.0           |           py36_0          70 KB  rapidsai
#     zstd-1.4.3                 |       h3b9ef0a_0         935 KB  conda-forge
#     thrift-cpp-0.12.0          |    hf3afdfd_1004         2.4 MB  conda-forge
#     ucx-1.7.0+g9d06c3a         |       cuda10.0_0         8.2 MB  rapidsai
#     openjpeg-2.3.1             |       h981e76c_3         475 KB  conda-forge
#     poppler-data-0.4.9         |                1         3.4 MB  conda-forge
#     boost-cpp-1.70.0           |       h8e57a91_2        21.1 MB  conda-forge
#     scikit-learn-0.22.2.post1  |   py36hcdab131_0         7.1 MB  conda-forge
#     locket-0.2.0               |             py_2           6 KB  conda-forge
#     tornado-6.0.4              |   py36h8c4c3a4_1         639 KB  conda-forge
#     curl-7.68.0                |       hf8cf82a_0         137 KB  conda-forge
#     scipy-1.4.1                |   py36h921218d_0        18.9 MB  conda-forge
#     fastrlock-0.4              |py36h831f99a_1001          32 KB  conda-forge
#     partd-1.1.0                |             py_0          17 KB  conda-forge
#     nccl-2.4.6.1               |       cuda10.0_0        66.5 MB  nvidia
#     numba-0.48.0               |   py36hb3f55d8_0         3.4 MB  conda-forge
#     decorator-4.4.2            |             py_0          11 KB  conda-forge
#     krb5-1.16.4                |       h2fd8d38_0         1.4 MB  conda-forge
#     cupy-7.2.0                 |   py36he57b8b9_1        15.2 MB  conda-forge
#     xorg-kbproto-1.0.7         |    h14c3975_1002          26 KB  conda-forge
#     liblapack-3.8.0            |      14_openblas          10 KB  conda-forge
#     fsspec-0.6.3               |             py_0          48 KB  conda-forge
#     pyopenssl-19.1.0           |             py_1          47 KB  conda-forge
#     hdf5-1.10.5                |nompi_h3c11f04_1104         3.1 MB  conda-forge
#     gcsfs-0.6.0                |             py_0          19 KB  conda-forge
#     proj-6.3.0                 |       hc80f0dc_0        10.3 MB  conda-forge
#     libprotobuf-3.8.0          |       h8b12597_0         4.7 MB  conda-forge
#     libcudf-0.12.0             |       cuda10.0_0       119.2 MB  rapidsai
#     xorg-libx11-1.6.9          |       h516909a_0         918 KB  conda-forge
#     urllib3-1.25.7             |   py36h9f0ad1d_1         160 KB  conda-forge
#     xorg-libice-1.0.10         |       h516909a_0          57 KB  conda-forge
#     fontconfig-2.13.1          |    h86ecdb6_1001         340 KB  conda-forge
#     google-auth-oauthlib-0.4.1 |             py_2          18 KB  conda-forge
#     cudatoolkit-10.0.130       |                0       380.0 MB  nvidia
#     libgdal-2.4.4              |       h2b6fda6_0        18.7 MB  conda-forge
#     geos-3.8.0                 |       he1b5a44_1         1.0 MB  conda-forge
#     libcumlprims-0.12          |       cuda10.0_9         6.5 MB  nvidia
#     parquet-cpp-1.5.1          |                2           3 KB  conda-forge
#     llvmlite-0.31.0            |   py36hfa65bc7_1         325 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     double-conversion-3.1.5    |       he1b5a44_2          85 KB  conda-forge
#     requests-2.23.0            |     pyh8c360ce_2          47 KB  conda-forge
#     hdf4-4.2.13                |    hf30be14_1003         964 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h516909a_0          18 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     libkml-1.3.0               |    h4fcabce_1010         643 KB  conda-forge
#     libpng-1.6.37              |       hed695b0_1         308 KB  conda-forge
#     libssh2-1.8.2              |       h22169c7_2         257 KB  conda-forge
#     blinker-1.4                |             py_1          13 KB  conda-forge
#     zict-2.0.0                 |             py_0          10 KB  conda-forge
#     c-ares-1.15.0              |    h516909a_1001         100 KB  conda-forge
#     re2-2020.03.03             |       he1b5a44_0         435 KB  conda-forge
#     markupsafe-1.1.1           |   py36h8c4c3a4_1          26 KB  conda-forge
#     dask-core-2.12.0           |             py_0         594 KB  conda-forge
#     rmm-0.12.0                 |           py36_0         353 KB  rapidsai
#     glog-0.4.0                 |       he1b5a44_1         104 KB  conda-forge
#     click-7.1.1                |     pyh8c360ce_0          64 KB  conda-forge
#     gdal-2.4.4                 |   py36h5f563d9_0         1.4 MB  conda-forge
#     xorg-libsm-1.2.3           |    h84519dc_1000          25 KB  conda-forge
#     snappy-1.1.8               |       he1b5a44_1          39 KB  conda-forge
#     libxml2-2.9.10             |       hee79883_0         1.3 MB  conda-forge
#     expat-2.2.9                |       he1b5a44_2         191 KB  conda-forge
#     libcuspatial-0.12.0        |       cuda10.0_0         1.6 MB  rapidsai
#     librmm-0.12.0              |       cuda10.0_0          53 KB  rapidsai
#     json-c-0.13.1              |    h14c3975_1001          71 KB  conda-forge
#     libopenblas-0.3.7          |       h5ec1e0e_6         7.6 MB  conda-forge
#     xorg-libxrender-0.9.10     |    h516909a_1002          31 KB  conda-forge
#     libcugraph-0.12.0          |       cuda10.0_0        18.9 MB  rapidsai
#     psutil-5.7.0               |   py36h8c4c3a4_1         324 KB  conda-forge
#     typing_extensions-3.7.4.1  |   py36h9f0ad1d_1          38 KB  conda-forge
#     libhwloc-2.1.0             |       h3c4fd83_0         2.7 MB  conda-forge
#     pynvml-8.0.4               |             py_0          31 KB  conda-forge
#     libspatialite-4.3.0a       |    ha48a99a_1034         3.1 MB  conda-forge
#     gflags-2.2.2               |    he1b5a44_1002         175 KB  conda-forge
#     xgboost-0.90.rapidsdev1    |   cuda10.0py36_1          12 KB  rapidsai/label/xgboost
#     libxcb-1.13                |    h14c3975_1002         396 KB  conda-forge
#     tzcode-2019a               |    h516909a_1002         429 KB  conda-forge
#     cryptography-2.8           |   py36h45558ae_2         628 KB  conda-forge
#     cloudpickle-1.3.0          |             py_0          24 KB  conda-forge
#     giflib-5.1.7               |       h516909a_1         455 KB  conda-forge
#     cytoolz-0.10.1             |   py36h516909a_0         431 KB  conda-forge
#     jinja2-2.11.1              |             py_0          94 KB  conda-forge
#     python-dateutil-2.8.1      |             py_0         220 KB  conda-forge
#     distributed-2.12.0         |           py36_0         993 KB  conda-forge
#     fastavro-0.22.13           |   py36h8c4c3a4_1         416 KB  conda-forge
#     pthread-stubs-0.4          |    h14c3975_1001           5 KB  conda-forge
#     requests-oauthlib-1.2.0    |             py_0          19 KB  conda-forge
#     dlpack-0.2                 |       he1b5a44_1          13 KB  conda-forge
#     cairo-1.16.0               |    hcf35c78_1003         1.5 MB  conda-forge
#     brotli-1.0.7               |    he1b5a44_1001         1.0 MB  conda-forge
#     pandas-0.25.3              |   py36hb3f55d8_0        11.4 MB  conda-forge
#     libcuml-0.12.0             |       cuda10.0_0        51.8 MB  rapidsai
#     arrow-cpp-0.15.0           |   py36h090bef1_2        18.1 MB  conda-forge
#     cugraph-0.12.0             |           py36_0         4.0 MB  rapidsai
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     kealib-1.4.12              |       hec59c27_0         172 KB  conda-forge
#     libpq-12.2                 |       hae5116b_0         2.6 MB  conda-forge
#     lz4-c-1.8.3                |    he1b5a44_1001         187 KB  conda-forge
#     google-auth-1.11.2         |             py_0          47 KB  conda-forge
#     libuuid-2.32.1             |    h14c3975_1000          26 KB  conda-forge
#     libnetcdf-4.7.3            |nompi_h9f9fd6a_101         1.3 MB  conda-forge
#     heapdict-1.0.1             |             py_0           7 KB  conda-forge
#     xerces-c-3.2.2             |    h8412b87_1004         1.7 MB  conda-forge
#     msgpack-python-1.0.0       |   py36hdb11119_1          91 KB  conda-forge
#     cuspatial-0.12.0           |           py36_0         574 KB  rapidsai
#     postgresql-12.2            |       hf1211e9_0         5.0 MB  conda-forge
#     libblas-3.8.0              |      14_openblas          10 KB  conda-forge
#     pixman-0.38.0              |    h516909a_1003         594 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h14c3975_1002           8 KB  conda-forge
#     icu-64.2                   |       he1b5a44_1        12.6 MB  conda-forge
#     libnvstrings-0.12.0        |       cuda10.0_0        30.1 MB  rapidsai
#     libdap4-3.20.4             |       hd3bb157_0        18.5 MB  conda-forge
#     pcre-8.44                  |       he1b5a44_0         261 KB  conda-forge
#     dask-2.12.0                |             py_0           4 KB  conda-forge
#     glib-2.58.3                |py36hd3ed26a_1003         3.3 MB  conda-forge
#     pytz-2019.3                |             py_0         237 KB  conda-forge
#     grpc-cpp-1.23.0            |       h18db393_0         4.5 MB  conda-forge
#     joblib-0.14.1              |             py_0         198 KB  conda-forge
#     bzip2-1.0.8                |       h516909a_2         396 KB  conda-forge
#     xorg-xproto-7.0.31         |    h14c3975_1007          72 KB  conda-forge
#     tblib-1.6.0                |             py_0          14 KB  conda-forge
#     libllvm8-8.0.1             |       hc9558a2_0        23.2 MB  conda-forge
#     gettext-0.19.8.1           |    hc5be6a0_1002         3.6 MB  conda-forge
#     py-xgboost-0.90.rapidsdev1 |   cuda10.0py36_1          87 KB  rapidsai/label/xgboost
#     jpeg-9c                    |    h14c3975_1001         251 KB  conda-forge
#     freetype-2.10.1            |       he06d7ca_0         877 KB  conda-forge
#     freexl-1.0.5               |    h14c3975_1002          43 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h14c3975_1002          27 KB  conda-forge
#     libevent-2.1.10            |       h72c5cf5_0         1.3 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.21 GB
#
# The following NEW packages will be INSTALLED:
#
#     arrow-cpp:            0.15.0-py36h090bef1_2          conda-forge
#     blinker:              1.4-py_1                       conda-forge
#     bokeh:                2.0.0-py36h9f0ad1d_0           conda-forge
#     boost-cpp:            1.70.0-h8e57a91_2              conda-forge
#     brotli:               1.0.7-he1b5a44_1001            conda-forge
#     bzip2:                1.0.8-h516909a_2               conda-forge
#     c-ares:               1.15.0-h516909a_1001           conda-forge
#     cachetools:           3.1.1-py_0                     conda-forge
#     cairo:                1.16.0-hcf35c78_1003           conda-forge
#     cfitsio:              3.470-hb60a0a2_2               conda-forge
#     click:                7.1.1-pyh8c360ce_0             conda-forge
#     cloudpickle:          1.3.0-py_0                     conda-forge
#     cudatoolkit:          10.0.130-0                     nvidia
#     cudf:                 0.12.0-py36_0                  rapidsai
#     cudnn:                7.6.0-cuda10.0_0               nvidia
#     cugraph:              0.12.0-py36_0                  rapidsai
#     cuml:                 0.12.0-cuda10.0_py36_0         rapidsai
#     cupy:                 7.2.0-py36he57b8b9_1           conda-forge
#     curl:                 7.68.0-hf8cf82a_0              conda-forge
#     cuspatial:            0.12.0-py36_0                  rapidsai
#     cytoolz:              0.10.1-py36h516909a_0          conda-forge
#     dask:                 2.12.0-py_0                    conda-forge
#     dask-core:            2.12.0-py_0                    conda-forge
#     dask-cudf:            0.12.0-py36_0                  rapidsai
#     decorator:            4.4.2-py_0                     conda-forge
#     distributed:          2.12.0-py36_0                  conda-forge
#     dlpack:               0.2-he1b5a44_1                 conda-forge
#     double-conversion:    3.1.5-he1b5a44_2               conda-forge
#     expat:                2.2.9-he1b5a44_2               conda-forge
#     fastavro:             0.22.13-py36h8c4c3a4_1         conda-forge
#     fastrlock:            0.4-py36h831f99a_1001          conda-forge
#     fontconfig:           2.13.1-h86ecdb6_1001           conda-forge
#     freetype:             2.10.1-he06d7ca_0              conda-forge
#     freexl:               1.0.5-h14c3975_1002            conda-forge
#     fsspec:               0.6.3-py_0                     conda-forge
#     gcsfs:                0.6.0-py_0                     conda-forge
#     gdal:                 2.4.4-py36h5f563d9_0           conda-forge
#     geos:                 3.8.0-he1b5a44_1               conda-forge
#     geotiff:              1.5.1-h38872f0_8               conda-forge
#     gettext:              0.19.8.1-hc5be6a0_1002         conda-forge
#     gflags:               2.2.2-he1b5a44_1002            conda-forge
#     giflib:               5.1.7-h516909a_1               conda-forge
#     glib:                 2.58.3-py36hd3ed26a_1003       conda-forge
#     glog:                 0.4.0-he1b5a44_1               conda-forge
#     google-auth:          1.11.2-py_0                    conda-forge
#     google-auth-oauthlib: 0.4.1-py_2                     conda-forge
#     grpc-cpp:             1.23.0-h18db393_0              conda-forge
#     hdf4:                 4.2.13-hf30be14_1003           conda-forge
#     hdf5:                 1.10.5-nompi_h3c11f04_1104     conda-forge
#     heapdict:             1.0.1-py_0                     conda-forge
#     icu:                  64.2-he1b5a44_1                conda-forge
#     jinja2:               2.11.1-py_0                    conda-forge
#     joblib:               0.14.1-py_0                    conda-forge
#     jpeg:                 9c-h14c3975_1001               conda-forge
#     json-c:               0.13.1-h14c3975_1001           conda-forge
#     kealib:               1.4.12-hec59c27_0              conda-forge
#     krb5:                 1.16.4-h2fd8d38_0              conda-forge
#     libblas:              3.8.0-14_openblas              conda-forge
#     libcblas:             3.8.0-14_openblas              conda-forge
#     libcudf:              0.12.0-cuda10.0_0              rapidsai
#     libcugraph:           0.12.0-cuda10.0_0              rapidsai
#     libcuml:              0.12.0-cuda10.0_0              rapidsai
#     libcumlprims:         0.12-cuda10.0_9                nvidia
#     libcurl:              7.68.0-hda55be3_0              conda-forge
#     libcuspatial:         0.12.0-cuda10.0_0              rapidsai
#     libdap4:              3.20.4-hd3bb157_0              conda-forge
#     libevent:             2.1.10-h72c5cf5_0              conda-forge
#     libgdal:              2.4.4-h2b6fda6_0               conda-forge
#     libgfortran-ng:       7.3.0-hdf63c60_5               conda-forge
#     libhwloc:             2.1.0-h3c4fd83_0               conda-forge
#     libiconv:             1.15-h516909a_1006             conda-forge
#     libkml:               1.3.0-h4fcabce_1010            conda-forge
#     liblapack:            3.8.0-14_openblas              conda-forge
#     libllvm8:             8.0.1-hc9558a2_0               conda-forge
#     libnetcdf:            4.7.3-nompi_h9f9fd6a_101       conda-forge
#     libnvstrings:         0.12.0-cuda10.0_0              rapidsai
#     libopenblas:          0.3.7-h5ec1e0e_6               conda-forge
#     libpng:               1.6.37-hed695b0_1              conda-forge
#     libpq:                12.2-hae5116b_0                conda-forge
#     libprotobuf:          3.8.0-h8b12597_0               conda-forge
#     librmm:               0.12.0-cuda10.0_0              rapidsai
#     libspatialite:        4.3.0a-ha48a99a_1034           conda-forge
#     libssh2:              1.8.2-h22169c7_2               conda-forge
#     libtiff:              4.1.0-hfc65ed5_0               conda-forge
#     libuuid:              2.32.1-h14c3975_1000           conda-forge
#     libxcb:               1.13-h14c3975_1002             conda-forge
#     libxgboost:           0.90.rapidsdev1-cuda10.0_1     rapidsai/label/xgboost
#     libxml2:              2.9.10-hee79883_0              conda-forge
#     llvmlite:             0.31.0-py36hfa65bc7_1          conda-forge
#     locket:               0.2.0-py_2                     conda-forge
#     lz4-c:                1.8.3-he1b5a44_1001            conda-forge
#     markupsafe:           1.1.1-py36h8c4c3a4_1           conda-forge
#     msgpack-python:       1.0.0-py36hdb11119_1           conda-forge
#     nccl:                 2.4.6.1-cuda10.0_0             nvidia
#     numba:                0.48.0-py36hb3f55d8_0          conda-forge
#     numpy:                1.18.1-py36h95a1406_0          conda-forge
#     nvstrings:            0.12.0-py36_0                  rapidsai
#     oauthlib:             3.0.1-py_0                     conda-forge
#     olefile:              0.46-py_0                      conda-forge
#     openjpeg:             2.3.1-h981e76c_3               conda-forge
#     packaging:            20.1-py_0                      conda-forge
#     pandas:               0.25.3-py36hb3f55d8_0          conda-forge
#     parquet-cpp:          1.5.1-2                        conda-forge
#     partd:                1.1.0-py_0                     conda-forge
#     pcre:                 8.44-he1b5a44_0                conda-forge
#     pillow:               7.0.0-py36h8328e55_1           conda-forge
#     pixman:               0.38.0-h516909a_1003           conda-forge
#     poppler:              0.67.0-h14e79db_8              conda-forge
#     poppler-data:         0.4.9-1                        conda-forge
#     postgresql:           12.2-hf1211e9_0                conda-forge
#     proj:                 6.3.0-hc80f0dc_0               conda-forge
#     psutil:               5.7.0-py36h8c4c3a4_1           conda-forge
#     pthread-stubs:        0.4-h14c3975_1001              conda-forge
#     py-xgboost:           0.90.rapidsdev1-cuda10.0py36_1 rapidsai/label/xgboost
#     pyarrow:              0.15.0-py36h8b68381_1          conda-forge
#     pyasn1:               0.4.8-py_0                     conda-forge
#     pyasn1-modules:       0.2.7-py_0                     conda-forge
#     pyjwt:                1.7.1-py_0                     conda-forge
#     pynvml:               8.0.4-py_0                     conda-forge
#     pyparsing:            2.4.6-py_0                     conda-forge
#     python-dateutil:      2.8.1-py_0                     conda-forge
#     pytz:                 2019.3-py_0                    conda-forge
#     pyyaml:               5.1.2-py36h516909a_0           conda-forge
#     re2:                  2020.03.03-he1b5a44_0          conda-forge
#     requests-oauthlib:    1.2.0-py_0                     conda-forge
#     rmm:                  0.12.0-py36_0                  rapidsai
#     rsa:                  4.0-py_0                       conda-forge
#     scikit-learn:         0.22.2.post1-py36hcdab131_0    conda-forge
#     scipy:                1.4.1-py36h921218d_0           conda-forge
#     snappy:               1.1.8-he1b5a44_1               conda-forge
#     sortedcontainers:     2.1.0-py_0                     conda-forge
#     tblib:                1.6.0-py_0                     conda-forge
#     thrift-cpp:           0.12.0-hf3afdfd_1004           conda-forge
#     toolz:                0.10.0-py_0                    conda-forge
#     tornado:              6.0.4-py36h8c4c3a4_1           conda-forge
#     typing_extensions:    3.7.4.1-py36h9f0ad1d_1         conda-forge
#     tzcode:               2019a-h516909a_1002            conda-forge
#     ucx:                  1.7.0+g9d06c3a-cuda10.0_0      rapidsai
#     ucx-py:               0.12.0+g9d06c3a-py36_0         rapidsai
#     uriparser:            0.9.3-he1b5a44_1               conda-forge
#     xerces-c:             3.2.2-h8412b87_1004            conda-forge
#     xgboost:              0.90.rapidsdev1-cuda10.0py36_1 rapidsai/label/xgboost
#     xorg-kbproto:         1.0.7-h14c3975_1002            conda-forge
#     xorg-libice:          1.0.10-h516909a_0              conda-forge
#     xorg-libsm:           1.2.3-h84519dc_1000            conda-forge
#     xorg-libx11:          1.6.9-h516909a_0               conda-forge
#     xorg-libxau:          1.0.9-h14c3975_0               conda-forge
#     xorg-libxdmcp:        1.1.3-h516909a_0               conda-forge
#     xorg-libxext:         1.3.4-h516909a_0               conda-forge
#     xorg-libxrender:      0.9.10-h516909a_1002           conda-forge
#     xorg-renderproto:     0.11.1-h14c3975_1002           conda-forge
#     xorg-xextproto:       7.3.0-h14c3975_1002            conda-forge
#     xorg-xproto:          7.0.31-h14c3975_1007           conda-forge
#     zict:                 2.0.0-py_0                     conda-forge
#     zstd:                 1.4.3-h3b9ef0a_0               conda-forge
#
# The following packages will be UPDATED:
#
#     cryptography:         2.2.2-py36h14c3975_0                                  --> 2.8-py36h45558ae_2    conda-forge
#     pyopenssl:            18.0.0-py36_0                                         --> 19.1.0-py_1           conda-forge
#     requests:             2.18.4-py36he2e5f8d_1                                 --> 2.23.0-pyh8c360ce_2   conda-forge
#     urllib3:              1.22-py36hbe7ace6_0                                   --> 1.25.7-py36h9f0ad1d_1 conda-forge
#
#
# Downloading and Extracting Packages
# bokeh-2.0.0          |  6.9 MB | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
# sortedcontainers-2.1 |   25 KB | : 100% 1.0/1 [00:00<00:00, 16.67it/s]
# cachetools-3.1.1     |   11 KB | : 100% 1.0/1 [00:00<00:00, 24.07it/s]
# poppler-0.67.0       |  8.9 MB | : 100% 1.0/1 [00:01<00:00,  1.37s/it]
# geotiff-1.5.1        |  279 KB | : 100% 1.0/1 [00:00<00:00,  9.65it/s]
# cudnn-7.6.0          | 216.6 MB | : 100% 1.0/1 [00:45<00:00, 45.90s/it]
# pyarrow-0.15.0       |  3.2 MB | : 100% 1.0/1 [00:00<00:00,  1.05it/s]
# xorg-libxext-1.3.4   |   51 KB | : 100% 1.0/1 [00:00<00:00, 20.90it/s]
# pyparsing-2.4.6      |   59 KB | : 100% 1.0/1 [00:00<00:00, 25.73it/s]
# olefile-0.46         |   31 KB | : 100% 1.0/1 [00:00<00:00, 26.20it/s]
# libcblas-3.8.0       |   10 KB | : 100% 1.0/1 [00:00<00:00, 18.99it/s]
# libgfortran-ng-7.3.0 |  1.7 MB | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# xorg-libxau-1.0.9    |   13 KB | : 100% 1.0/1 [00:00<00:00, 24.62it/s]
# uriparser-0.9.3      |   49 KB | : 100% 1.0/1 [00:00<00:00, 18.08it/s]
# pillow-7.0.0         |  652 KB | : 100% 1.0/1 [00:00<00:00,  5.38it/s]
# packaging-20.1       |   31 KB | : 100% 1.0/1 [00:00<00:00, 15.64it/s]
# oauthlib-3.0.1       |   82 KB | : 100% 1.0/1 [00:00<00:00, 13.97it/s]
# nvstrings-0.12.0     |  129 KB | : 100% 1.0/1 [00:02<00:00,  2.71s/it]
# cuml-0.12.0          |  9.1 MB | : 100% 1.0/1 [00:03<00:00,  3.60s/it]
# cfitsio-3.470        |  1.4 MB | : 100% 1.0/1 [00:00<00:00,  3.67it/s]
# libcurl-7.68.0       |  564 KB | : 100% 1.0/1 [00:00<00:00,  7.89it/s]
# rsa-4.0              |   27 KB | : 100% 1.0/1 [00:00<00:00, 23.54it/s]
# pyjwt-1.7.1          |   17 KB | : 100% 1.0/1 [00:00<00:00, 17.85it/s]
# cudf-0.12.0          |  9.9 MB | : 100% 1.0/1 [00:03<00:00,  3.46s/it]
# libxgboost-0.90.rapi | 32.8 MB | : 100% 1.0/1 [00:10<00:00, 10.01s/it]
# numpy-1.18.1         |  5.2 MB | : 100% 1.0/1 [00:01<00:00,  1.15s/it]
# pyyaml-5.1.2         |  184 KB | : 100% 1.0/1 [00:00<00:00, 14.48it/s]
# ucx-py-0.12.0+g9d06c |  270 KB | : 100% 1.0/1 [00:02<00:00,  2.29s/it]
# libiconv-1.15        |  2.0 MB | : 100% 1.0/1 [00:00<00:00,  3.21it/s]
# libtiff-4.1.0        |  595 KB | : 100% 1.0/1 [00:00<00:00,  5.30it/s]
# dask-cudf-0.12.0     |   70 KB | : 100% 1.0/1 [00:01<00:00,  1.44s/it]
# zstd-1.4.3           |  935 KB | : 100% 1.0/1 [00:00<00:00,  5.29it/s]
# thrift-cpp-0.12.0    |  2.4 MB | : 100% 1.0/1 [00:00<00:00,  2.16it/s]
# ucx-1.7.0+g9d06c3a   |  8.2 MB | : 100% 1.0/1 [00:03<00:00,  3.86s/it]
# openjpeg-2.3.1       |  475 KB | : 100% 1.0/1 [00:00<00:00,  6.47it/s]
# poppler-data-0.4.9   |  3.4 MB | : 100% 1.0/1 [00:00<00:00,  1.68it/s]
# boost-cpp-1.70.0     | 21.1 MB | : 100% 1.0/1 [00:08<00:00,  8.58s/it]
# scikit-learn-0.22.2. |  7.1 MB | : 100% 1.0/1 [00:01<00:00,  1.60s/it]
# locket-0.2.0         |    6 KB | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# tornado-6.0.4        |  639 KB | : 100% 1.0/1 [00:00<00:00,  4.86it/s]
# curl-7.68.0          |  137 KB | : 100% 1.0/1 [00:00<00:00, 19.12it/s]
# scipy-1.4.1          | 18.9 MB | : 100% 1.0/1 [00:03<00:00,  3.37s/it]
# fastrlock-0.4        |   32 KB | : 100% 1.0/1 [00:00<00:00, 13.77it/s]
# partd-1.1.0          |   17 KB | : 100% 1.0/1 [00:00<00:00, 29.50it/s]
# nccl-2.4.6.1         | 66.5 MB | : 100% 1.0/1 [00:17<00:00, 17.53s/it]
# numba-0.48.0         |  3.4 MB | : 100% 1.0/1 [00:01<00:00,  1.01s/it]
# decorator-4.4.2      |   11 KB | : 100% 1.0/1 [00:00<00:00, 30.42it/s]
# krb5-1.16.4          |  1.4 MB | : 100% 1.0/1 [00:00<00:00,  3.32it/s]
# cupy-7.2.0           | 15.2 MB | : 100% 1.0/1 [00:03<00:00,  3.45s/it]
# xorg-kbproto-1.0.7   |   26 KB | : 100% 1.0/1 [00:00<00:00, 25.02it/s]
# liblapack-3.8.0      |   10 KB | : 100% 1.0/1 [00:00<00:00, 21.93it/s]
# fsspec-0.6.3         |   48 KB | : 100% 1.0/1 [00:00<00:00, 20.40it/s]
# pyopenssl-19.1.0     |   47 KB | : 100% 1.0/1 [00:00<00:00, 18.27it/s]
# hdf5-1.10.5          |  3.1 MB | : 100% 1.0/1 [00:00<00:00,  1.91it/s]
# gcsfs-0.6.0          |   19 KB | : 100% 1.0/1 [00:00<00:00, 25.44it/s]
# proj-6.3.0           | 10.3 MB | : 100% 1.0/1 [00:02<00:00,  2.95s/it]
# libprotobuf-3.8.0    |  4.7 MB | : 100% 1.0/1 [00:00<00:00,  1.08it/s]
# libcudf-0.12.0       | 119.2 MB | : 100% 1.0/1 [00:38<00:00, 38.02s/it]
# xorg-libx11-1.6.9    |  918 KB | : 100% 1.0/1 [00:00<00:00,  3.67it/s]
# urllib3-1.25.7       |  160 KB | : 100% 1.0/1 [00:00<00:00,  9.16it/s]
# xorg-libice-1.0.10   |   57 KB | : 100% 1.0/1 [00:00<00:00, 23.42it/s]
# fontconfig-2.13.1    |  340 KB | : 100% 1.0/1 [00:00<00:00,  7.64it/s]
# google-auth-oauthlib |   18 KB | : 100% 1.0/1 [00:00<00:00, 25.15it/s]
# cudatoolkit-10.0.130 | 380.0 MB | : 100% 1.0/1 [01:18<00:00, 78.08s/it]
# libgdal-2.4.4        | 18.7 MB | : 100% 1.0/1 [00:03<00:00,  3.30s/it]
# geos-3.8.0           |  1.0 MB | : 100% 1.0/1 [00:00<00:00,  2.89it/s]
# libcumlprims-0.12    |  6.5 MB | : 100% 1.0/1 [00:05<00:00,  5.38s/it]
# parquet-cpp-1.5.1    |    3 KB | : 100% 1.0/1 [00:00<00:00, 25.66it/s]
# llvmlite-0.31.0      |  325 KB | : 100% 1.0/1 [00:00<00:00,  9.96it/s]
# pyasn1-0.4.8         |   53 KB | : 100% 1.0/1 [00:00<00:00, 17.18it/s]
# double-conversion-3. |   85 KB | : 100% 1.0/1 [00:00<00:00, 11.75it/s]
# requests-2.23.0      |   47 KB | : 100% 1.0/1 [00:00<00:00, 14.73it/s]
# hdf4-4.2.13          |  964 KB | : 100% 1.0/1 [00:00<00:00,  4.82it/s]
# xorg-libxdmcp-1.1.3  |   18 KB | : 100% 1.0/1 [00:00<00:00, 23.22it/s]
# pyasn1-modules-0.2.7 |   60 KB | : 100% 1.0/1 [00:00<00:00, 15.20it/s]
# libkml-1.3.0         |  643 KB | : 100% 1.0/1 [00:00<00:00,  5.21it/s]
# libpng-1.6.37        |  308 KB | : 100% 1.0/1 [00:00<00:00, 10.91it/s]
# libssh2-1.8.2        |  257 KB | : 100% 1.0/1 [00:00<00:00,  8.88it/s]
# blinker-1.4          |   13 KB | : 100% 1.0/1 [00:00<00:00, 21.98it/s]
# zict-2.0.0           |   10 KB | : 100% 1.0/1 [00:00<00:00, 18.03it/s]
# c-ares-1.15.0        |  100 KB | : 100% 1.0/1 [00:00<00:00, 21.50it/s]
# re2-2020.03.03       |  435 KB | : 100% 1.0/1 [00:00<00:00,  8.66it/s]
# markupsafe-1.1.1     |   26 KB | : 100% 1.0/1 [00:00<00:00, 29.28it/s]
# dask-core-2.12.0     |  594 KB | : 100% 1.0/1 [00:00<00:00,  5.13it/s]
# rmm-0.12.0           |  353 KB | : 100% 1.0/1 [00:01<00:00,  1.38s/it]
# glog-0.4.0           |  104 KB | : 100% 1.0/1 [00:00<00:00, 19.82it/s]
# click-7.1.1          |   64 KB | : 100% 1.0/1 [00:00<00:00, 21.02it/s]
# gdal-2.4.4           |  1.4 MB | : 100% 1.0/1 [00:00<00:00,  3.27it/s]
# xorg-libsm-1.2.3     |   25 KB | : 100% 1.0/1 [00:00<00:00, 26.58it/s]
# snappy-1.1.8         |   39 KB | : 100% 1.0/1 [00:00<00:00, 20.97it/s]
# libxml2-2.9.10       |  1.3 MB | : 100% 1.0/1 [00:00<00:00,  2.62it/s]
# expat-2.2.9          |  191 KB | : 100% 1.0/1 [00:00<00:00, 12.77it/s]
# libcuspatial-0.12.0  |  1.6 MB | : 100% 1.0/1 [00:00<00:00,  1.16it/s]
# librmm-0.12.0        |   53 KB | : 100% 1.0/1 [00:01<00:00,  1.31s/it]
# json-c-0.13.1        |   71 KB | : 100% 1.0/1 [00:00<00:00, 22.54it/s]
# libopenblas-0.3.7    |  7.6 MB | : 100% 1.0/1 [00:01<00:00,  1.37s/it]
# xorg-libxrender-0.9. |   31 KB | : 100% 1.0/1 [00:00<00:00, 26.56it/s]
# libcugraph-0.12.0    | 18.9 MB | : 100% 1.0/1 [00:05<00:00,  5.73s/it]
# psutil-5.7.0         |  324 KB | : 100% 1.0/1 [00:00<00:00,  8.43it/s]
# typing_extensions-3. |   38 KB | : 100% 1.0/1 [00:00<00:00, 20.70it/s]
# libhwloc-2.1.0       |  2.7 MB | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# pynvml-8.0.4         |   31 KB | : 100% 1.0/1 [00:00<00:00, 25.24it/s]
# libspatialite-4.3.0a |  3.1 MB | : 100% 1.0/1 [00:00<00:00,  1.66it/s]
# gflags-2.2.2         |  175 KB | : 100% 1.0/1 [00:00<00:00, 13.72it/s]
# xgboost-0.90.rapidsd |   12 KB | : 100% 1.0/1 [00:01<00:00,  1.27s/it]
# libxcb-1.13          |  396 KB | : 100% 1.0/1 [00:00<00:00,  5.78it/s]
# tzcode-2019a         |  429 KB | : 100% 1.0/1 [00:00<00:00,  2.63it/s]
# cryptography-2.8     |  628 KB | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# cloudpickle-1.3.0    |   24 KB | : 100% 1.0/1 [00:00<00:00, 24.77it/s]
# giflib-5.1.7         |  455 KB | : 100% 1.0/1 [00:00<00:00,  8.47it/s]
# cytoolz-0.10.1       |  431 KB | : 100% 1.0/1 [00:00<00:00,  8.13it/s]
# jinja2-2.11.1        |   94 KB | : 100% 1.0/1 [00:00<00:00, 17.00it/s]
# python-dateutil-2.8. |  220 KB | : 100% 1.0/1 [00:00<00:00, 16.67it/s]
# distributed-2.12.0   |  993 KB | : 100% 1.0/1 [00:00<00:00,  2.83it/s]
# fastavro-0.22.13     |  416 KB | : 100% 1.0/1 [00:00<00:00,  8.95it/s]
# pthread-stubs-0.4    |    5 KB | : 100% 1.0/1 [00:00<00:00, 28.92it/s]
# requests-oauthlib-1. |   19 KB | : 100% 1.0/1 [00:00<00:00, 24.04it/s]
# dlpack-0.2           |   13 KB | : 100% 1.0/1 [00:00<00:00, 27.88it/s]
# cairo-1.16.0         |  1.5 MB | : 100% 1.0/1 [00:00<00:00,  3.09it/s]
# brotli-1.0.7         |  1.0 MB | : 100% 1.0/1 [00:00<00:00,  5.94it/s]
# pandas-0.25.3        | 11.4 MB | : 100% 1.0/1 [00:02<00:00,  2.51s/it]
# libcuml-0.12.0       | 51.8 MB | : 100% 1.0/1 [00:14<00:00, 14.71s/it]
# arrow-cpp-0.15.0     | 18.1 MB | : 100% 1.0/1 [00:03<00:00,  3.45s/it]
# cugraph-0.12.0       |  4.0 MB | : 100% 1.0/1 [00:03<00:00,  3.48s/it]
# toolz-0.10.0         |   46 KB | : 100% 1.0/1 [00:00<00:00, 14.04it/s]
# kealib-1.4.12        |  172 KB | : 100% 1.0/1 [00:00<00:00, 16.47it/s]
# libpq-12.2           |  2.6 MB | : 100% 1.0/1 [00:00<00:00,  1.41it/s]
# lz4-c-1.8.3          |  187 KB | : 100% 1.0/1 [00:00<00:00,  9.20it/s]
# google-auth-1.11.2   |   47 KB | : 100% 1.0/1 [00:00<00:00, 18.13it/s]
# libuuid-2.32.1       |   26 KB | : 100% 1.0/1 [00:00<00:00, 26.50it/s]
# libnetcdf-4.7.3      |  1.3 MB | : 100% 1.0/1 [00:00<00:00,  1.78it/s]
# heapdict-1.0.1       |    7 KB | : 100% 1.0/1 [00:00<00:00, 24.32it/s]
# xerces-c-3.2.2       |  1.7 MB | : 100% 1.0/1 [00:00<00:00,  1.89it/s]
# msgpack-python-1.0.0 |   91 KB | : 100% 1.0/1 [00:00<00:00, 21.61it/s]
# cuspatial-0.12.0     |  574 KB | : 100% 1.0/1 [00:01<00:00, 45.04s/it]
# postgresql-12.2      |  5.0 MB | : 100% 1.0/1 [00:00<00:00,  1.14it/s]
# libblas-3.8.0        |   10 KB | : 100% 1.0/1 [00:00<00:00, 24.86it/s]
# pixman-0.38.0        |  594 KB | : 100% 1.0/1 [00:00<00:00,  7.38it/s]
# xorg-renderproto-0.1 |    8 KB | : 100% 1.0/1 [00:00<00:00, 23.46it/s]
# icu-64.2             | 12.6 MB | : 100% 1.0/1 [00:02<00:00,  2.20s/it]
# libnvstrings-0.12.0  | 30.1 MB | : 100% 1.0/1 [00:10<00:00, 10.08s/it]
# libdap4-3.20.4       | 18.5 MB | : 100% 1.0/1 [00:02<00:00,  2.82s/it]
# pcre-8.44            |  261 KB | : 100% 1.0/1 [00:00<00:00, 11.04it/s]
# dask-2.12.0          |    4 KB | : 100% 1.0/1 [00:00<00:00, 24.66it/s]
# glib-2.58.3          |  3.3 MB | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
# pytz-2019.3          |  237 KB | : 100% 1.0/1 [00:00<00:00,  4.29it/s]
# grpc-cpp-1.23.0      |  4.5 MB | : 100% 1.0/1 [00:01<00:00,  1.03s/it]
# joblib-0.14.1        |  198 KB | : 100% 1.0/1 [00:00<00:00,  7.90it/s]
# bzip2-1.0.8          |  396 KB | : 100% 1.0/1 [00:00<00:00,  9.07it/s]
# xorg-xproto-7.0.31   |   72 KB | : 100% 1.0/1 [00:00<00:00, 16.97it/s]
# tblib-1.6.0          |   14 KB | : 100% 1.0/1 [00:00<00:00, 27.18it/s]
# libllvm8-8.0.1       | 23.2 MB | : 100% 1.0/1 [00:04<00:00,  4.13s/it]
# gettext-0.19.8.1     |  3.6 MB | : 100% 1.0/1 [00:01<00:00,  1.28s/it]
# py-xgboost-0.90.rapi |   87 KB | : 100% 1.0/1 [00:01<00:00,  1.69s/it]
# jpeg-9c              |  251 KB | : 100% 1.0/1 [00:00<00:00, 10.18it/s]
# freetype-2.10.1      |  877 KB | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
# freexl-1.0.5         |   43 KB | : 100% 1.0/1 [00:00<00:00, 21.12it/s]
# xorg-xextproto-7.3.0 |   27 KB | : 100% 1.0/1 [00:00<00:00, 18.09it/s]
# libevent-2.1.10      |  1.3 MB | : 100% 1.0/1 [00:00<00:00,  2.46it/s]
# done
# done
# done
# Copying shared object files to /usr/lib
# Copying RAPIDS compatible xgboost
#
# ************************************************
# Your Google Colab instance has RAPIDS installed!
# ************************************************
# ***********************************************************************
# Let us check on those pyarrow and cffi versions...
# ***********************************************************************
#
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# unloaded pyarrow 0.14.1
# loaded pyarrow 0.15.0
# You're now running pyarrow 0.15.0 and are good to go!
# unloaded cffi 1.14.0
# loaded cffi 1.11.5

# %% [markdown]
# # Data Analysis

# %%
import cudf
import numpy as np
import dask_cudf

# %%
bank_df = cudf.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/bank-full.csv',sep=';')

# %% [markdown]
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur", "student","blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
#
# related with the last contact of the current campaign:
#
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# other attributes:
#
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# output variable (desired target):
#
# 17 - y - has the client subscribed a term deposit? (binary: "yes","no")

# %%
! nvidia-smi
# Out:
# Fri Mar 20 15:54:34 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0    29W /  70W |    413MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
print("rows: ", bank_df.shape[0])
print("columns: ", bank_df.shape[1])
# Out:
# rows:  45211
# columns:  17

# %%
bank_df.dtypes

# %%
bank_df.isnull().sum()

# %%
bank_df['y'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int32

# %% [markdown]
# # Benchmarking against dask cudf vs cudf

# %%
import time

# %%
start_time = time.time()
bank_df.describe()
end_time = time.time()
print("Time taken on GPU : %s" %(end_time - start_time))
# Out:
# Time taken on GPU : 0.11950492858886719

# %%
dcudf = dask_cudf.from_cudf(bank_df, npartitions=2)

# %%
start_time = time.time()
dcudf.describe()
end_time = time.time()
print("Time taken on GPU : %s" %(end_time - start_time))
# Out:
# Time taken on GPU : 0.48287105560302734

# %% [markdown]
# # Exploring Data

# %%
bank_df.describe()
# Out:
#                 age        balance  ...         pdays      previous
# count  45211.000000   45211.000000  ...  45211.000000  45211.000000
# mean      40.936210    1362.272058  ...     40.197828      0.580323
# std       10.618762    3044.765829  ...    100.128746      2.303441
# min       18.000000   -8019.000000  ...     -1.000000      0.000000
# 25%       33.000000      72.000000  ...     -1.000000      0.000000
# 50%       39.000000     448.000000  ...     -1.000000      0.000000
# 75%       48.000000    1428.000000  ...     -1.000000      0.000000
# max       95.000000  102127.000000  ...    871.000000    275.000000
#
# [8 rows x 7 columns]

# %%
bank_df.groupby(['marital', 'y']).agg({'balance':'mean'})
# Out:
#                   balance
# marital  y
# divorced no   1107.095747
#          yes  1707.964630
# married  no   1370.746228
#          yes  1915.810163
# single   no   1235.869921
#          yes  1674.875523

# %%
bank_df.groupby(['marital', 'y']).agg({'balance':'mean', 'y': 'count'})
# Out:
#                   balance      y
# marital  y
# divorced no   1107.095747   4585
#          yes  1707.964630    622
# married  no   1370.746228  24459
#          yes  1915.810163   2755
# single   no   1235.869921  10878
#          yes  1674.875523   1912

# %%
loan_outcome = bank_df.groupby(['loan', 'y']).agg({'balance':'mean','y':'count'})

# %%
print(loan_outcome)
# Out:
#               balance      y
# loan y
# no   no   1413.228726  33162
#      yes  1897.001041   4805
# yes  no    766.481953   6760
#      yes   883.642562    484

# %%
def convert_hour(duration):
    return duration / 60

# %%
bank_df['duration_hour'] = bank_df['duration'].applymap(convert_hour)

# %%
bank_df.head()
# Out:
#    age           job  marital  education  ... previous  poutcome   y duration_hour
# 0   58    management  married   tertiary  ...        0   unknown  no      4.350000
# 1   44    technician   single  secondary  ...        0   unknown  no      2.516667
# 2   33  entrepreneur  married  secondary  ...        0   unknown  no      1.266667
# 3   47   blue-collar  married    unknown  ...        0   unknown  no      1.533333
# 4   33       unknown   single    unknown  ...        0   unknown  no      3.300000
#
# [5 rows x 18 columns]

# %%
bank_df.groupby('y').campaign.mean()
# Out:
# y
# no     2.846350
# yes    2.141047
# Name: campaign, dtype: float64

# %%
bank_campaign_df = bank_df.query("campaign <= 8")

# %%
bank_df['education'].value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int32
